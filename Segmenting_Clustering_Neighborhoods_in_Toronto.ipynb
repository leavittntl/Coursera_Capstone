# %% [markdown]
# # Explore and cluster the neighborhoods in Toronto:
#
# 1)Scraping, cleaning and data wrangling. <br>
# 2)Add latitude and longitude coordinates. <br>
# 3)Explore and cluster the neighborhoods in Toronto.

# %% [markdown]
# ### 1)Scraping, cleaning and data wrangling.

# %% [markdown]
# Import all of the libraries that are needed for data scraping/cleaning/wrangling

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Pull HTML code and store it in local variable

# %%
page = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
page.status_code
#A response of 200 indecates a successful 'get' request
# Out:
# 200

# %%
#Pass HTML through BeautifulSoup function and print the result
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of postal codes of Canada: M - Wikipedia
#   </title>
#   <script>
# ...

# %% [markdown]
# Navigate and find table within parent HTML. Once table is found, reassign to local variable.

# %%
html = list(soup.children)[2]
list(html.children)
# Out:
# ['\n',
#  <head>
#  <meta charset="utf-8"/>
#  <title>List of postal codes of Canada: M - Wikipedia</title>
# ...

# %%
wholeTable = html.find_all('table')[0]
wholeTable
# Out:
# <table cellpadding="2" cellspacing="0" rules="all" style="width:100%; border-collapse:collapse; border:1px solid #ccc;">
# <tbody><tr>
# <td style="width:11%; vertical-align:top; color:#ccc;">
# <p><b>M1A</b><br/><span style="font-size:85%;"><i>Not assigned</i></span>
# </p>
# </td>
# <td style="width:11%; vertical-align:top; color:#ccc;">
# <p><b>M2A</b><br/><span style="font-size:85%;"><i>Not assigned</i></span>
# </p>
# </td>
# <td style="width:11%; vertical-align:top;">
# <p><b>M3A</b><br/><span style="font-size:85%;"><a href="/wiki/North_York" title="North York">North York</a><br/>(<a href="/wiki/Parkwoods" title="Parkwoods">Parkwoods</a>)</span>
# </p>
# </td>
# <td style="width:11%; vertical-align:top;">
# <p><b>M4A</b><br/><span style="font-size:85%;"><a href="/wiki/North_York" title="North York">North York</a><br/>(<a href="/wiki/Victoria_Village" title="Victoria Village">Victoria Village</a>)</span>
# </p>
# </td>
# <td style="width:11%; vertical-align:top;">
# ...

# %%
list(wholeTable.children)
# Out:
# ['\n',
#  <tbody><tr>
#  <td style="width:11%; vertical-align:top; color:#ccc;">
#  <p><b>M1A</b><br/><span style="font-size:85%;"><i>Not assigned</i></span>
#  </p>
#  </td>
#  <td style="width:11%; vertical-align:top; color:#ccc;">
#  <p><b>M2A</b><br/><span style="font-size:85%;"><i>Not assigned</i></span>
#  </p>
#  </td>
#  <td style="width:11%; vertical-align:top;">
#  <p><b>M3A</b><br/><span style="font-size:85%;"><a href="/wiki/North_York" title="North York">North York</a><br/>(<a href="/wiki/Parkwoods" title="Parkwoods">Parkwoods</a>)</span>
#  </p>
#  </td>
#  <td style="width:11%; vertical-align:top;">
#  <p><b>M4A</b><br/><span style="font-size:85%;"><a href="/wiki/North_York" title="North York">North York</a><br/>(<a href="/wiki/Victoria_Village" title="Victoria Village">Victoria Village</a>)</span>
#  </p>
#  </td>
#  <td style="width:11%; vertical-align:top;">
# ...

# %%
allCells = wholeTable.find_all('td')
len(allCells)
# Out:
# 180

# %%
i = 0
PostCodes = []
BoroughANDNeighborhood = []
while i < 181:
    PostCodes.append(wholeTable.find_all('b')[i].get_text())
    BoroughANDNeighborhood.append(wholeTable.find_all('span')[i].get_text())
    #Neigghborhood
    print("PostCode is {} and BoroughANDNeighborhood is {}".format(PostCodes[i], BoroughANDNeighborhood[i]))
    i += 1
# Out:
# PostCode is M1A and BoroughANDNeighborhood is Not assigned
# PostCode is M2A and BoroughANDNeighborhood is Not assigned
# PostCode is M3A and BoroughANDNeighborhood is North York(Parkwoods)
# PostCode is M4A and BoroughANDNeighborhood is North York(Victoria Village)
# PostCode is M5A and BoroughANDNeighborhood is Downtown Toronto(Regent Park / Harbourfront)
# PostCode is M6A and BoroughANDNeighborhood is North York(Lawrence Manor / Lawrence Heights)
# PostCode is M7A and BoroughANDNeighborhood is Queen's Park(Ontario Provincial Government)
# PostCode is M8A and BoroughANDNeighborhood is Not assigned
# PostCode is M9A and BoroughANDNeighborhood is Etobicoke(Islington Avenue)
# PostCode is M1B and BoroughANDNeighborhood is Scarborough(Malvern / Rouge)
# PostCode is M2B and BoroughANDNeighborhood is Not assigned
# PostCode is M3B and BoroughANDNeighborhood is North York(Don Mills)North
# PostCode is M4B and BoroughANDNeighborhood is East York(Parkview Hill / Woodbine Gardens)
# ...

# %%
len(BoroughANDNeighborhood)
# Out:
# 180

# %%
i = 0
Borough = []
Neighborhood = []
firstHalf = []
secondHalf = []
while i < 180:
    
    firstHalf = BoroughANDNeighborhood[i].split("(")[0]
    Borough.append(firstHalf)
    
    if len(BoroughANDNeighborhood[i].split("(")) > 1:
        secondHalf = (BoroughANDNeighborhood[i].split("(")[1])
    else:
        secondHalf = BoroughANDNeighborhood[i].split("(")[0]
        
    Neighborhood.append(secondHalf)
    
    print("Borough is {} and Neighborhood is {}".format(Borough[i], Neighborhood[i]))
    i += 1
# Out:
# Borough is Not assigned and Neighborhood is Not assigned
# Borough is Not assigned and Neighborhood is Not assigned
# Borough is North York and Neighborhood is Parkwoods)
# Borough is North York and Neighborhood is Victoria Village)
# Borough is Downtown Toronto and Neighborhood is Regent Park / Harbourfront)
# Borough is North York and Neighborhood is Lawrence Manor / Lawrence Heights)
# Borough is Queen's Park and Neighborhood is Ontario Provincial Government)
# Borough is Not assigned and Neighborhood is Not assigned
# Borough is Etobicoke and Neighborhood is Islington Avenue)
# Borough is Scarborough and Neighborhood is Malvern / Rouge)
# Borough is Not assigned and Neighborhood is Not assigned
# Borough is North York and Neighborhood is Don Mills)North
# Borough is East York and Neighborhood is Parkview Hill / Woodbine Gardens)
# Borough is Downtown Toronto and Neighborhood is Garden District, Ryerson)
# Borough is North York and Neighborhood is Glencairn)
# ...

# %%
#Confirm proper length
len(Borough)
# Out:
# 180

# %%
#Clean up Neighborhood
i = 0
while i < 180:
    
    Neighborhood[i] = Neighborhood[i].replace(')', '').replace(' /', ',')
    
    
    print("Neighborhood is {}".format(Neighborhood[i]))
    i += 1
# Out:
# Neighborhood is Not assigned
# Neighborhood is Not assigned
# Neighborhood is Parkwoods
# Neighborhood is Victoria Village
# Neighborhood is Regent Park, Harbourfront
# Neighborhood is Lawrence Manor, Lawrence Heights
# Neighborhood is Ontario Provincial Government
# Neighborhood is Not assigned
# Neighborhood is Islington Avenue
# Neighborhood is Malvern, Rouge
# Neighborhood is Not assigned
# Neighborhood is Don MillsNorth
# Neighborhood is Parkview Hill, Woodbine Gardens
# Neighborhood is Garden District, Ryerson
# Neighborhood is Glencairn
# Neighborhood is Not assigned
# Neighborhood is Not assigned
# Neighborhood is West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Neighborhood is Rouge Hill, Port Union, Highland Creek
# Neighborhood is Not assigned
# Neighborhood is Don MillsSouth
# Neighborhood is Woodbine Heights
# Neighborhood is St. James Town
# Neighborhood is Humewood-Cedarvale
# Neighborhood is Not assigned
# Neighborhood is Not assigned
# ...

# %%
list_of_tuples = list(zip(PostCodes, Borough, Neighborhood))

df = pd.DataFrame(list_of_tuples,
                  columns = ['PostCodes', 'Borough', 'Neighborhood'])

df
# Out:
#     PostCodes           Borough  \
# 0         M1A      Not assigned
# 1         M2A      Not assigned
# 2         M3A        North York
# 3         M4A        North York
# 4         M5A  Downtown Toronto
# ..        ...               ...
# 175       M5Z      Not assigned
# 176       M6Z      Not assigned
# 177       M7Z      Not assigned
# 178       M8Z         Etobicoke
# 179       M9Z      Not assigned
#
#                                           Neighborhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# 177                                       Not assigned
# ...

# %%
#Clear any row that has no 'Borough'
df2 = df[df.Borough != 'Not assigned']

df2
# Out:
#     PostCodes                                            Borough  \
# 2         M3A                                         North York
# 3         M4A                                         North York
# 4         M5A                                   Downtown Toronto
# 5         M6A                                         North York
# 6         M7A                                       Queen's Park
# ..        ...                                                ...
# 160       M8X                                          Etobicoke
# 165       M4Y                                   Downtown Toronto
# 168       M7Y  East TorontoBusiness reply mail Processing Cen...
# 169       M8Y                                          Etobicoke
# 178       M8Z                                          Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# ...

# %%
#Reset Index, drop old
df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
#     PostCodes                                            Borough  \
# 0         M3A                                         North York
# 1         M4A                                         North York
# 2         M5A                                   Downtown Toronto
# 3         M6A                                         North York
# 4         M7A                                       Queen's Park
# ..        ...                                                ...
# 98        M8X                                          Etobicoke
# 99        M4Y                                   Downtown Toronto
# 100       M7Y  East TorontoBusiness reply mail Processing Cen...
# 101       M8Y                                          Etobicoke
# 102       M8Z                                          Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# ...

# %%
df2.shape
# Out:
# (103, 3)

# %% [markdown]
# ## End of first section

# %% [markdown]
# ## 2)Add latitude and longitude coordinates.

# %%
pip install geocoder
# Out:
# ...
#      |████████████████████████████████| 98 kB 4.8 MB/s eta 0:00:011
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geocoder # import geocoder

# %% [markdown]
# This package did not work for me, so I used the provided CSV to append the lat and long columns.

# %%
# initialize your variable to None
#lat_lng_coords = None


# loop until you get the coordinates
#while(lat_lng_coords is None):
    #g = geocoder.google('Toronto, Ontario')
    #lat_lng_coords = g.latlng
    #print(g.latlng)

#latitude.append(lat_lng_coords[0])
#longitude.append(lat_lng_coords[1])

# %%
#Read in CSV data
lat_lng_coords_df = pd.read_csv('Geospatial_Coordinates.csv')
lat_lng_coords_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
#Set 'key' column names equal
lat_lng_coords_df = lat_lng_coords_df.rename(columns={"Postal Code": "PostCodes"})

# %%
df_lat_lng = pd.merge(df2, lat_lng_coords_df, on='PostCodes')

# %%
df_lat_lng
# Out:
#     PostCodes                                            Borough  \
# 0         M3A                                         North York
# 1         M4A                                         North York
# 2         M5A                                   Downtown Toronto
# 3         M6A                                         North York
# 4         M7A                                       Queen's Park
# ..        ...                                                ...
# 98        M8X                                          Etobicoke
# 99        M4Y                                   Downtown Toronto
# 100       M7Y  East TorontoBusiness reply mail Processing Cen...
# 101       M8Y                                          Etobicoke
# 102       M8Z                                          Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# ...

# %% [markdown]
# ## End of second section

# %% [markdown]
# ## 3)Explore and cluster the neighborhoods in Toronto.

# %%
#Find all unique values with 'Toronto' in 'Borough'
df_lat_lng['Borough'].unique()
# Out:
# array(['North York', 'Downtown Toronto', "Queen's Park", 'Etobicoke',
#        'Scarborough', 'East York', 'York', 'East Toronto', 'West Toronto',
#        'East YorkEast Toronto', 'Central Toronto',
#        'MississaugaCanada Post Gateway Processing Centre',
#        'Downtown TorontoStn A PO Boxes25 The Esplanade',
#        'EtobicokeNorthwest',
#        'East TorontoBusiness reply mail Processing Centre969 Eastern'],
#       dtype=object)

# %%
#Filter df down to only 'Toronto' related values
df_Toronto = df_lat_lng[(df_lat_lng['Borough']=='Downtown Toronto') | (df_lat_lng['Borough']=='East Toronto') | (df_lat_lng['Borough']=='West Toronto') | (df_lat_lng['Borough']=='East YorkEast Toronto') | (df_lat_lng['Borough']=='Central Toronto') | (df_lat_lng['Borough']=='Downtown TorontoStn A PO Boxes25 The Esplanade') | (df_lat_lng['Borough']=='East TorontoBusiness reply mail Processing Centre969 Eastern')]
df_Toronto
# Out:
#     PostCodes                                            Borough  \
# 2         M5A                                   Downtown Toronto
# 9         M5B                                   Downtown Toronto
# 15        M5C                                   Downtown Toronto
# 19        M4E                                       East Toronto
# 20        M5E                                   Downtown Toronto
# 24        M5G                                   Downtown Toronto
# 25        M6G                                   Downtown Toronto
# 30        M5H                                   Downtown Toronto
# 31        M6H                                       West Toronto
# 35        M4J                              East YorkEast Toronto
# 36        M5J                                   Downtown Toronto
# 37        M6J                                       West Toronto
# 41        M4K                                       East Toronto
# ...

# %% [markdown]
# ## Import additional libraies for maping/visuals

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import json # library to handle JSON files

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
# create map of Toronto using latitude and longitude values
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(df_Toronto['Latitude'], df_Toronto['Longitude'], df_Toronto['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ## Intergrate Foursquare

# %%
CLIENT_ID = 'C4MNDL1LR5W55W5YGR2VTH3WFM40JKALTLRJWHAA153YWUFS' # your Foursquare ID
CLIENT_SECRET = 'IMMVE4P4CMKN0PVUHTRX3NGRFMMN1APMJICKBIC0UXCSZDKT' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: C4MNDL1LR5W55W5YGR2VTH3WFM40JKALTLRJWHAA153YWUFS
# CLIENT_SECRET:IMMVE4P4CMKN0PVUHTRX3NGRFMMN1APMJICKBIC0UXCSZDKT

# %% [markdown]
# Let's explore Kensington Market:

# %%
df_Kensington = df_Toronto.loc[df_Toronto['Neighborhood'] == 'Kensington Market, Chinatown, Grange Park']
df_Kensington
# Out:
#    PostCodes           Borough                               Neighborhood  \
# 84       M5T  Downtown Toronto  Kensington Market, Chinatown, Grange Park
#
#      Latitude  Longitude
# 84  43.653206 -79.400049

# %%
neighborhood_latitude = df_Kensington.at[84, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = df_Kensington.at[84, 'Longitude'] # neighborhood longitude value

neighborhood_name = df_Kensington.at[84, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Kensington Market, Chinatown, Grange Park are 43.6532057, -79.4000493.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API



radius = 500 # define radius


# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=C4MNDL1LR5W55W5YGR2VTH3WFM40JKALTLRJWHAA153YWUFS&client_secret=IMMVE4P4CMKN0PVUHTRX3NGRFMMN1APMJICKBIC0UXCSZDKT&v=20180605&ll=43.6532057,-79.4000493&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60e07fe9bd0a7d1e4c1218b0'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Kensington',
#   'headerFullLocation': 'Kensington, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 66,
#   'suggestedBounds': {'ne': {'lat': 43.6577057045, 'lng': -79.3938414091248},
#    'sw': {'lat': 43.6487056955, 'lng': -79.40625719087521}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50427a03e4b08d9f5931f593',
#        'name': 'Seven Lives - Tacos y Mariscos',
#        'location': {'address': '69 Kensington Ave',
#         'crossStreet': 'Baldwin St',
#         'lat': 43.65441817160925,
# ...

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# <ipython-input-252-561c05f0fdd1>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues = json_normalize(venues) # flatten JSON
#                              name             categories        lat        lng
# 0  Seven Lives - Tacos y Mariscos     Mexican Restaurant  43.654418 -79.400545
# 1            Banh Mi Nguyen Huong  Vietnamese Restaurant  43.653628 -79.398376
# 2               The Moonbean Cafe                   Café  43.654147 -79.400182
# 3             Blackbird Baking Co                 Bakery  43.654897 -79.400619
# 4        Essence of Life Organics        Organic Grocery  43.654111 -79.400431

# %% [markdown]
# Number of venuses returned from Foursquare:

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 66 venues were returned by Foursquare.

# %%
#Let's check for unique venues to get a sense of the diversity
nearby_venues['categories'].unique()
# Out:
# array(['Mexican Restaurant', 'Vietnamese Restaurant', 'Café', 'Bakery',
#        'Organic Grocery', 'Arts & Crafts Store', 'Coffee Shop',
#        'Food Truck', 'Dessert Shop', 'Gourmet Shop', 'Grocery Store',
#        'Cheese Shop', 'Fish Market', 'Farmers Market', 'Wine Bar',
#        'Comfort Food Restaurant', 'Gaming Cafe', 'Cocktail Bar',
#        'Donut Shop', 'Belgian Restaurant', 'Caribbean Restaurant', 'Bar',
#        'Beer Bar', 'Jazz Club', 'Pizza Place',
#        'Vegetarian / Vegan Restaurant', 'Burger Joint', 'Record Shop',
#        'Tea Room', 'Italian Restaurant', 'Food Court', 'Burrito Place',
#        'Doner Restaurant', 'Japanese Restaurant', 'Park', 'Brewery',
#        'Bed & Breakfast', 'Pharmacy', 'Breakfast Spot', 'Hospital',
#        'Juice Bar', 'Poutine Place', 'Filipino Restaurant', 'Skate Park',
#        'Deli / Bodega', 'Smoothie Shop'], dtype=object)

# %%
nearby_venues.groupby('categories').count().sort_values(by=['name'])
# Out:
#                                name  lat  lng
# categories
# Arts & Crafts Store               1    1    1
# Food Court                        1    1    1
# Food Truck                        1    1    1
# Gourmet Shop                      1    1    1
# Hospital                          1    1    1
# Italian Restaurant                1    1    1
# Japanese Restaurant               1    1    1
# Jazz Club                         1    1    1
# Filipino Restaurant               1    1    1
# Juice Bar                         1    1    1
# Pharmacy                          1    1    1
# Pizza Place                       1    1    1
# Poutine Place                     1    1    1
# Record Shop                       1    1    1
# Skate Park                        1    1    1
# Smoothie Shop                     1    1    1
# Tea Room                          1    1    1
# Organic Grocery                   1    1    1
# Farmers Market                    1    1    1
# ...

# %% [markdown]
# ### There are a significant amount of venues here. I'm more of a morning person, so let's see where all of the cafes and bakeries are located. Finaly, try to cluster the "night life" locations vs morning locations.

# %%
nearby_venues
# Out:
#                               name             categories        lat  \
# 0   Seven Lives - Tacos y Mariscos     Mexican Restaurant  43.654418
# 1             Banh Mi Nguyen Huong  Vietnamese Restaurant  43.653628
# 2                The Moonbean Cafe                   Café  43.654147
# 3              Blackbird Baking Co                 Bakery  43.654897
# 4         Essence of Life Organics        Organic Grocery  43.654111
# ..                             ...                    ...        ...
# 61    Nom Nom Nom Poutine & Crêpes          Poutine Place  43.652111
# 62                           Kanto    Filipino Restaurant  43.652167
# 63              Bathurst Skatepark             Skate Park  43.650943
# 64                         Druxy's          Deli / Bodega  43.653388
# 65                   Booster Juice          Smoothie Shop  43.653657
#
#           lng
# 0  -79.400545
# 1  -79.398376
# 2  -79.400182
# 3  -79.400619
# 4  -79.400431
# ..        ...
# 61 -79.404786
# ...

# %%
#Create new column
nearby_venues["NewClass"] = ''

# %%
nearby_venues
# Out:
#                               name             categories        lat  \
# 0   Seven Lives - Tacos y Mariscos     Mexican Restaurant  43.654418
# 1             Banh Mi Nguyen Huong  Vietnamese Restaurant  43.653628
# 2                The Moonbean Cafe                   Café  43.654147
# 3              Blackbird Baking Co                 Bakery  43.654897
# 4         Essence of Life Organics        Organic Grocery  43.654111
# ..                             ...                    ...        ...
# 61    Nom Nom Nom Poutine & Crêpes          Poutine Place  43.652111
# 62                           Kanto    Filipino Restaurant  43.652167
# 63              Bathurst Skatepark             Skate Park  43.650943
# 64                         Druxy's          Deli / Bodega  43.653388
# 65                   Booster Juice          Smoothie Shop  43.653657
#
#           lng NewClass
# 0  -79.400545
# 1  -79.398376
# 2  -79.400182
# 3  -79.400619
# 4  -79.400431
# ..        ...      ...
# ...

# %%
nearby_venues["NewClass"][nearby_venues.categories == 'Café'] = 'Morning Spot'
# Out:
# <ipython-input-271-3805a7c98e31>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nearby_venues["NewClass"][nearby_venues.categories == 'Café'] = 'Morning Spot'

# %% [markdown]
# Define rest of the 'Morning Spots'

# %%
nearby_venues["NewClass"][nearby_venues.categories == 'Bakery'] = 'Morning Spot'
nearby_venues["NewClass"][nearby_venues.categories == 'Coffee Shop'] = 'Morning Spot'
nearby_venues["NewClass"][nearby_venues.categories == 'Gaming Cafe'] = 'Morning Spot'
nearby_venues["NewClass"][nearby_venues.categories == 'Donut Shop'] = 'Morning Spot'
nearby_venues["NewClass"][nearby_venues.categories == 'Breakfast Spot'] = 'Morning Spot'
nearby_venues["NewClass"][nearby_venues.categories == 'Bed & Breakfast'] = 'Morning Spot'
nearby_venues["NewClass"][nearby_venues.categories == 'Tea Room'] = 'Morning Spot'
nearby_venues["NewClass"][nearby_venues.categories == 'Smoothie Shop'] = 'Morning Spot'
nearby_venues["NewClass"][nearby_venues.categories == 'Juice Bar'] = 'Morning Spot'
# Out:
# <ipython-input-273-ab9ff35c7bf4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nearby_venues["NewClass"][nearby_venues.categories == 'Bakery'] = 'Morning Spot'
# <ipython-input-273-ab9ff35c7bf4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nearby_venues["NewClass"][nearby_venues.categories == 'Coffee Shop'] = 'Morning Spot'
# <ipython-input-273-ab9ff35c7bf4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
nearby_venues["NewClass"][nearby_venues.NewClass == ''] = "After Morning Spot"
# Out:
# <ipython-input-279-78b7ae40d1f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nearby_venues["NewClass"][nearby_venues.NewClass == ''] = "After Morning Spot"

# %%
nearby_venues
# Out:
#                               name             categories        lat  \
# 0   Seven Lives - Tacos y Mariscos     Mexican Restaurant  43.654418
# 1             Banh Mi Nguyen Huong  Vietnamese Restaurant  43.653628
# 2                The Moonbean Cafe                   Café  43.654147
# 3              Blackbird Baking Co                 Bakery  43.654897
# 4         Essence of Life Organics        Organic Grocery  43.654111
# ..                             ...                    ...        ...
# 61    Nom Nom Nom Poutine & Crêpes          Poutine Place  43.652111
# 62                           Kanto    Filipino Restaurant  43.652167
# 63              Bathurst Skatepark             Skate Park  43.650943
# 64                         Druxy's          Deli / Bodega  43.653388
# 65                   Booster Juice          Smoothie Shop  43.653657
#
#           lng            NewClass
# 0  -79.400545  After Morning Spot
# 1  -79.398376  After Morning Spot
# ...

# %% [markdown]
# Let's map this new classification against their corrisponding coordinates.

# %%
# create map of Toronto using latitude and longitude values
map_Kensington = folium.Map(location=[neighborhood_latitude, neighborhood_longitude], zoom_start=15)

MS_Values = nearby_venues.loc[nearby_venues['NewClass'] == 'Morning Spot']
AMS_Values = nearby_venues.loc[nearby_venues['NewClass'] == 'After Morning Spot']

# add markers to map
for lat, lng, newClass, cat,  in zip(MS_Values['lat'], MS_Values['lng'], MS_Values['NewClass'], MS_Values['categories']):
    label = folium.Popup('Class:' + newClass + ', category:' + cat, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Kensington)  
    
# add markers to map
for lat, lng, newClass, cat,  in zip(AMS_Values['lat'], AMS_Values['lng'], AMS_Values['NewClass'], AMS_Values['categories']):
    label = folium.Popup('Class:' + newClass + ', category:' + cat, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='green',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Kensington)  
    
map_Kensington
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# Even though there is not a big seperation between morning and nonmorning spots, there does seem to be a slightly higher clustering of morning spots on the north side of Kensington, versus the south west side.
