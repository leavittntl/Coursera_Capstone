# %% [markdown]
# # Coffee Shop exploration (Within NH, VT, and ME)

# %% [markdown]
# ## Idea:
# I would like to plan a trip that spans across VT, NH, and ME. During this trip, I want to experience the best coffee shops, based on popularity, each state has to offer, within 100,000 meters of each of the three state's capitals. I would also like to check the frequencies for the most common coffee shops, then cross compare the most popular to the most common/frequent. With both of these, I feel like I'll be able to map out the best route as I drive across each of the three states and find the most popular coffee shops that are NOT also the most common.

# %% [markdown]
# ## Target Audience:
# Coffee lovers who travel Northern New England.

# %% [markdown]
# ## Problem to solve:
# Avoid drinking a bad cup of coffee while on vacation.

# %% [markdown]
# ---

# %% [markdown]
# ## Process:
#
# 1)Import all librairs needed:<br>

# %%
import pandas as pd
import numpy as np

#Find latitudinal and longitudinal data for a given location
# !pip install geopy
from geopy.geocoders import Nominatim

#--Addtional libraires for mapping:--
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import json # library to handle JSON files

#--To communicate with FourSquare API--
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Out:
# Requirement already satisfied: geopy in /Users/gustave/opt/anaconda3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/gustave/opt/anaconda3/lib/python3.8/site-packages (from geopy) (1.52)
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# 2)Generate map showing all three states, using Nominatim (from geopy.geocoders) to accuire lat and long for the three states, then folium.map to generate a map of these three state capitals. Augusta, ME will be used as the lat and long passed to folium, as it best represents the center of the desired mapping area.<br><br>
# 3)Pull all coffee shops within 100,000 meters of the three state capitals and save each within their own dataframe. Using the FourSquare API "explore" endpoint, three requests will be submitted. Each request containing a "LIMIT" of 500, with a radius of 100,000 meters, as well as two values for the categoryId parameter '4bf58dd8d48988d1e0931735' (for coffee shops) and '4bf58dd8d48988d16d941735' (for cafes), and finaly the "sortByPopularity" will be set you '1'.<br><br>
# 4)Clean out any rows that do not fall within the desired cities.<br><br>
# 5)Take the top row from each of the three cities dataframes and save them to a new dataframe named TopThree_City_df. This will be used to map the top three most popular coffee shops.<br><br>
# 6)Go back to the original dataframes and run a GROUPBY and COUNT on the "name" columns to generate a frequencies table.<br><br>
# 7)Finally, I'll take the most popular and most common/frequent coffee shops and map them to get a sense of where I should go and which routes I can avoid.<br><br>

# %% [markdown]
# ## Data:

# %%
CLIENT_ID = 'C4MNDL1LR5W55W5YGR2VTH3WFM40JKALTLRJWHAA153YWUFS' # your Foursquare ID
CLIENT_SECRET = 'IMMVE4P4CMKN0PVUHTRX3NGRFMMN1APMJICKBIC0UXCSZDKT' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: C4MNDL1LR5W55W5YGR2VTH3WFM40JKALTLRJWHAA153YWUFS
# CLIENT_SECRET:IMMVE4P4CMKN0PVUHTRX3NGRFMMN1APMJICKBIC0UXCSZDKT

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Vermont:

# %%
address = 'Burlington, Vermont'

geolocator = Nominatim(user_agent="vt_explorer")
location = geolocator.geocode(address)
latitude_vt = location.latitude
longitude_vt = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude_vt, longitude_vt))
# Out:
# The geograpical coordinate of Toronto are 44.4761601, -73.212906.

# %%
LIMIT = 500 # limit of number of venues returned by Foursquare API



radius = 100000 # define radius

# create URL
url_vt = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&sortByPopularity=1&categoryId=4bf58dd8d48988d1e0931735,4bf58dd8d48988d16d941735'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude_vt, 
    longitude_vt,
    radius,
    LIMIT)
url_vt # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=C4MNDL1LR5W55W5YGR2VTH3WFM40JKALTLRJWHAA153YWUFS&client_secret=IMMVE4P4CMKN0PVUHTRX3NGRFMMN1APMJICKBIC0UXCSZDKT&v=20180605&ll=44.4761601,-73.212906&radius=100000&limit=500&sortByPopularity=1&categoryId=4bf58dd8d48988d1e0931735,4bf58dd8d48988d16d941735'

# %%
results_vt = requests.get(url_vt).json()
results_vt
# Out:
# {'meta': {'code': 200, 'requestId': '60e870c876d5ad59a2115fa7'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Burlington',
#   'headerFullLocation': 'Burlington',
#   'headerLocationGranularity': 'city',
#   'query': 'coffee shop',
#   'totalResults': 110,
#   'suggestedBounds': {'ne': {'lat': 45.3761610000009,
#     'lng': -71.95394652208812},
#    'sw': {'lat': 43.576159199999104, 'lng': -74.47186547791189}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53b2ec27498e609aa439d410',
#        'name': 'UVM Medical Center Harvest Café',
#        'location': {'address': '111 Colchester Ave',
#         'crossStreet': 'Medical Center Campus, McClure Lobby',
#         'lat': 44.4801873,
#         'lng': -73.1952631,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.4801873,
#           'lng': -73.1952631}],
#         'distance': 1471,
#         'postalCode': '05401',
#         'cc': 'US',
#         'city': 'Burlington',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['111 Colchester Ave (Medical Center Campus, McClure Lobby)',
#          'Burlington, VT 05401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53b2ec27498e609aa439d410-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a6500759e0d5424e2fc45dd',
#        'name': 'Tim Hortons',
#        'location': {'address': '124 Chemin Ridge',
#         'lat': 45.067424,
#         'lng': -73.457205,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.067424,
#           'lng': -73.457205}],
#         'distance': 68591,
#         'postalCode': 'J0J 1V0',
#         'cc': 'CA',
#         'city': 'Saint-Bernard-de-Lacolle',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['124 Chemin Ridge',
#          'Saint-Bernard-de-Lacolle QC J0J 1V0',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a6500759e0d5424e2fc45dd-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5e654b90ff57a30008ec77f1',
#        'name': 'Starbucks',
#        'location': {'address': '54 Sunderland Way',
#         'lat': 44.504437,
#         'lng': -73.138335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.504437,
#           'lng': -73.138335}],
#         'distance': 6706,
#         'postalCode': '05452',
#         'cc': 'US',
#         'city': 'Essex Junction',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['54 Sunderland Way',
#          'Essex Junction, VT 05452',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5e654b90ff57a30008ec77f1-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6f6c7af964a520f8ef2ce3',
#        'name': 'Starbucks',
#        'location': {'address': '1150 Williston Rd',
#         'crossStreet': 'at Small Meadows Shopping Ctr',
#         'lat': 44.46884,
#         'lng': -73.17805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.46884,
#           'lng': -73.17805},
#          {'label': 'entrance', 'lat': 44.468782, 'lng': -73.178098}],
#         'distance': 2886,
#         'postalCode': '05403',
#         'cc': 'US',
#         'city': 'South Burlington',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['1150 Williston Rd (at Small Meadows Shopping Ctr)',
#          'South Burlington, VT 05403',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6f6c7af964a520f8ef2ce3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5af367cf23a2e6002cfc3460',
#        'name': 'Maplefields Mobile. US Ave',
#        'location': {'lat': 44.68233283027385,
#         'lng': -73.44790263470287,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.68233283027385,
#           'lng': -73.44790263470287}],
#         'distance': 29562,
#         'postalCode': '12903',
#         'cc': 'US',
#         'city': 'Plattsburgh',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Plattsburgh, NY 12903', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5af367cf23a2e6002cfc3460-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5946adff08815818ea623279',
#        'name': 'Vermont Artisan Coffee & Tea Co',
#        'location': {'address': '11 Cabin Ln',
#         'lat': 44.394481259790375,
#         'lng': -72.7199344010911,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.394481259790375,
#           'lng': -72.7199344010911},
#          {'label': 'entrance', 'lat': 44.395798, 'lng': -72.720176}],
#         'distance': 40225,
#         'postalCode': '05677',
#         'cc': 'US',
#         'city': 'Waterbury Center',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['11 Cabin Ln',
#          'Waterbury Center, VT 05677',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '580233746'}},
#       'referralId': 'e-0-5946adff08815818ea623279-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5e4580128f54b10008579000',
#        'name': 'Kru Coffee',
#        'location': {'address': '2 Church Street',
#         'lat': 44.480189,
#         'lng': -73.21254,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.480189,
#           'lng': -73.21254}],
#         'distance': 449,
#         'postalCode': '05401',
#         'cc': 'US',
#         'city': 'Burlington',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['2 Church Street',
#          'Burlington, VT 05401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5e4580128f54b10008579000-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c92daae4b0ee0d742ce5c0',
#        'name': 'Tim Hortons',
#        'location': {'address': '400, Boul. Croisetiere',
#         'lat': 45.31239082017981,
#         'lng': -73.21962149570089,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.31239082017981,
#           'lng': -73.21962149570089}],
#         'distance': 93089,
#         'postalCode': 'J2X 1G9',
#         'cc': 'CA',
#         'city': 'Saint-Jean-sur-Richelieu',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['400, Boul. Croisetiere',
#          'Saint-Jean-sur-Richelieu QC J2X 1G9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50c92daae4b0ee0d742ce5c0-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53bb3707498e86566e9961dd',
#        'name': 'The Hub',
#        'location': {'address': '27 Market St',
#         'lat': 43.6771444604585,
#         'lng': -73.75028806932336,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6771444604585,
#           'lng': -73.75028806932336}],
#         'distance': 98783,
#         'postalCode': '12815',
#         'cc': 'US',
#         'city': 'Brant Lake',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['27 Market St',
#          'Brant Lake, NY 12815',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '89866872'}},
#       'referralId': 'e-0-53bb3707498e86566e9961dd-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53571481498ec983506f2382',
#        'name': 'Falls General Store',
#        'location': {'address': '7 Cox Brook Rd',
#         'crossStreet': 'at VT Route 12',
#         'lat': 44.1721580296016,
#         'lng': -72.65061858429067,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.1721580296016,
#           'lng': -72.65061858429067}],
#         'distance': 56128,
#         'postalCode': '05664',
#         'cc': 'US',
#         'city': 'Northfield Falls',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['7 Cox Brook Rd (at VT Route 12)',
#          'Northfield Falls, VT 05664',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53571481498ec983506f2382-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '517e66cc498e5b407788d4c9',
#        'name': 'Tim Hortons',
#        'location': {'address': '825, Rue Lucien-chenier',
#         'lat': 45.287889732937515,
#         'lng': -72.99317210912704,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.287889732937515,
#           'lng': -72.99317210912704}],
#         'distance': 92007,
#         'postalCode': 'J2N 0A9',
#         'cc': 'CA',
#         'city': 'Farnham',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['825, Rue Lucien-chenier',
#          'Farnham QC J2N 0A9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-517e66cc498e5b407788d4c9-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d39d1038e7fa90008e86e8b',
#        'name': 'Brio Coffeeworks',
#        'location': {'address': '266 Pine St Ste 116',
#         'crossStreet': 'Kilburn St',
#         'lat': 44.472164,
#         'lng': -73.21463,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.472164,
#           'lng': -73.21463}],
#         'distance': 465,
#         'postalCode': '05401',
#         'cc': 'US',
#         'neighborhood': 'South End',
#         'city': 'Burlington',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['266 Pine St Ste 116 (Kilburn St)',
#          'Burlington, VT 05401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d39d1038e7fa90008e86e8b-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c111a393ce120a11c23091c',
#        'name': 'Three Mountain Cafe',
#        'location': {'address': 'Mad River Green',
#         'crossStreet': 'at Rte 100',
#         'lat': 44.18409807580681,
#         'lng': -72.83872493748524,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.18409807580681,
#           'lng': -72.83872493748524},
#          {'label': 'entrance', 'lat': 44.183871, 'lng': -72.839193}],
#         'distance': 44099,
#         'postalCode': '05673',
#         'cc': 'US',
#         'city': 'Waitsfield',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['Mad River Green (at Rte 100)',
#          'Waitsfield, VT 05673',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c111a393ce120a11c23091c-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5401d095498e7c589029224e',
#        'name': 'Tim Hortons',
#        'location': {'lat': 45.288799,
#         'lng': -73.230292,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.288799,
#           'lng': -73.230292}],
#         'distance': 90472,
#         'cc': 'CA',
#         'city': 'Saint-Jean-sur-Richelieu',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['Saint-Jean-sur-Richelieu QC', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5401d095498e7c589029224e-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5fb3eacfb0c9e65a6d05e8fa',
#        'name': 'Starbucks',
#        'location': {'lat': 44.50698,
#         'lng': -73.18022,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.50698,
#           'lng': -73.18022}],
#         'distance': 4302,
#         'postalCode': '05446',
#         'cc': 'US',
#         'city': 'Colchester',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['Colchester, VT 05446', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5fb3eacfb0c9e65a6d05e8fa-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b2fd88af964a52018f124e3',
#        'name': 'Starbucks',
#        'location': {'address': '2072 Burlington Town Ctr',
#         'crossStreet': 'at Cherry & Church St',
#         'lat': 44.47873105,
#         'lng': -73.21394403,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.47873105,
#           'lng': -73.21394403}],
#         'distance': 297,
#         'postalCode': '05402',
#         'cc': 'US',
#         'city': 'Burlington',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['2072 Burlington Town Ctr (at Cherry & Church St)',
#          'Burlington, VT 05402',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b2fd88af964a52018f124e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1a5f58eac020a1942843c2',
#        'name': 'Turtle Island Cafe',
#        'location': {'address': '3790 Main St',
#         'lat': 44.364006060799284,
#         'lng': -73.39147342658205,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.364006060799284,
#           'lng': -73.39147342658205}],
#         'distance': 18905,
#         'postalCode': '12996',
#         'cc': 'US',
#         'city': 'Willsboro',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['3790 Main St',
#          'Willsboro, NY 12996',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1a5f58eac020a1942843c2-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b45ca14f964a5205e1026e3',
#        'name': 'Starbucks',
#        'location': {'address': '580 Shelburne Rd #9',
#         'crossStreet': 'at Gateway Shopping Ctr',
#         'lat': 44.448757,
#         'lng': -73.20813,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.448757,
#           'lng': -73.20813},
#          {'label': 'entrance', 'lat': 44.448672, 'lng': -73.208246}],
#         'distance': 3073,
#         'postalCode': '05403',
#         'cc': 'US',
#         'city': 'South Burlington',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['580 Shelburne Rd #9 (at Gateway Shopping Ctr)',
#          'South Burlington, VT 05403',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b45ca14f964a5205e1026e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc85436caa5a1cdb6ef9ce7',
#        'name': 'Café Rouge',
#        'location': {'address': '32, rue principale',
#         'lat': 45.121203660964966,
#         'lng': -72.98807322978973,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.121203660964966,
#           'lng': -72.98807322978973}],
#         'distance': 73969,
#         'postalCode': 'J0J 1A0',
#         'cc': 'CA',
#         'city': 'Bedford',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['32, rue principale',
#          'Bedford QC J0J 1A0',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cc85436caa5a1cdb6ef9ce7-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c241820a852c92885ace26c',
#        'name': 'Tim Hortons',
#        'location': {'address': '234 Boul St Luc',
#         'crossStreet': 'Bernier',
#         'lat': 45.35196426420319,
#         'lng': -73.29452314297674,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.35196426420319,
#           'lng': -73.29452314297674}],
#         'distance': 97705,
#         'postalCode': 'J2W 1C2',
#         'cc': 'CA',
#         'city': 'Saint-Jean-sur-Richelieu',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['234 Boul St Luc (Bernier)',
#          'Saint-Jean-sur-Richelieu QC J2W 1C2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c241820a852c92885ace26c-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbf4e08ba9776b063dafec8',
#        'name': 'Tim Hortons',
#        'location': {'address': '1615 Rue Du Sud',
#         'lat': 45.190763997481874,
#         'lng': -72.7544970810414,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.190763997481874,
#           'lng': -72.7544970810414}],
#         'distance': 87392,
#         'postalCode': 'J2K 2Z4',
#         'cc': 'CA',
#         'city': 'Cowansville',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1615 Rue Du Sud',
#          'Cowansville QC J2K 2Z4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbf4e08ba9776b063dafec8-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51193cc0e4b0b0ae7b705a0f',
#        'name': 'Adirondack Coffee Roasters',
#        'location': {'address': '373 State Route 3 Ste 1',
#         'lat': 44.69661417997656,
#         'lng': -73.48536507917994,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.69661417997656,
#           'lng': -73.48536507917994}],
#         'distance': 32693,
#         'postalCode': '12901',
#         'cc': 'US',
#         'city': 'Plattsburgh',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['373 State Route 3 Ste 1',
#          'Plattsburgh, NY 12901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '71248090'}},
#       'referralId': 'e-0-51193cc0e4b0b0ae7b705a0f-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0969ac6071a5931ae1dd32',
#        'name': 'Original General Store',
#        'location': {'address': '3963 Route 100',
#         'crossStreet': 'at Upper Michigan Rd',
#         'lat': 43.77280866173594,
#         'lng': -72.81308203593792,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.77280866173594,
#           'lng': -72.81308203593792}],
#         'distance': 84563,
#         'cc': 'US',
#         'city': 'Pittsfield',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['3963 Route 100 (at Upper Michigan Rd)',
#          'Pittsfield, VT',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '83646805'}},
#       'referralId': 'e-0-4c0969ac6071a5931ae1dd32-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf93ec65317a5935bec007f',
#        'name': 'Tim Hortons',
#        'location': {'address': '180 Omer-marcil',
#         'lat': 45.333189244986315,
#         'lng': -73.29354733228689,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.333189244986315,
#           'lng': -73.29354733228689}],
#         'distance': 95615,
#         'postalCode': 'J2W 2V1',
#         'cc': 'CA',
#         'city': 'Saint-Jean-sur-Richelieu',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['180 Omer-marcil',
#          'Saint-Jean-sur-Richelieu QC J2W 2V1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf93ec65317a5935bec007f-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53bfe384498ed50a2f05d780',
#        'name': 'Tim Hortons',
#        'location': {'address': '1325 Rue Douglas',
#         'lat': 45.34225988473816,
#         'lng': -73.28469268977642,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.34225988473816,
#           'lng': -73.28469268977642}],
#         'distance': 96579,
#         'postalCode': 'J2W 0J2',
#         'cc': 'CA',
#         'city': 'Saint-Jean-sur-Richelieu',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1325 Rue Douglas',
#          'Saint-Jean-sur-Richelieu QC J2W 0J2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53bfe384498ed50a2f05d780-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53668050498e95b5eecd0697',
#        'name': 'Scout & Company',
#        'location': {'address': '237 North Ave',
#         'crossStreet': 'Berry Street',
#         'lat': 44.48788966526624,
#         'lng': -73.22525887519734,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.48788966526624,
#           'lng': -73.22525887519734},
#          {'label': 'entrance', 'lat': 44.487897, 'lng': -73.225324}],
#         'distance': 1633,
#         'postalCode': '05401',
#         'cc': 'US',
#         'city': 'Burlington',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['237 North Ave (Berry Street)',
#          'Burlington, VT 05401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53668050498e95b5eecd0697-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4baf935df964a5204f0c3ce3',
#        'name': 'Tim Hortons',
#        'location': {'address': '370, Boul. Du Seminaire Nord',
#         'lat': 45.310577024878626,
#         'lng': -73.26564162969584,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.310577024878626,
#           'lng': -73.26564162969584}],
#         'distance': 92979,
#         'postalCode': 'J3B 5L2',
#         'cc': 'CA',
#         'city': 'Saint-Jean-sur-Richelieu',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['370, Boul. Du Seminaire Nord',
#          'Saint-Jean-sur-Richelieu QC J3B 5L2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4baf935df964a5204f0c3ce3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d974a4d9d5a990008cf4101',
#        'name': 'Kestrel Coffee',
#        'location': {'address': '47 Maple St',
#         'lat': 44.473176,
#         'lng': -73.217883,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.473176,
#           'lng': -73.217883}],
#         'distance': 516,
#         'postalCode': '05401',
#         'cc': 'US',
#         'city': 'Burlington',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['47 Maple St',
#          'Burlington, VT 05401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d974a4d9d5a990008cf4101-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bbe0e5f89b06a002c608510',
#        'name': 'Nomad Coffee',
#        'location': {'address': '208 Flynn Ave',
#         'crossStreet': 'Briggs St',
#         'lat': 44.4566535949707,
#         'lng': -73.21746063232422,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.4566535949707,
#           'lng': -73.21746063232422}],
#         'distance': 2201,
#         'postalCode': '05401',
#         'cc': 'US',
#         'city': 'Burlington',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['208 Flynn Ave (Briggs St)',
#          'Burlington, VT 05401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bbe0e5f89b06a002c608510-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c54265d30f92d7f68dbf2b9',
#        'name': 'Café Van Houtte',
#        'location': {'address': '935C Boul du Séminaire N',
#         'lat': 45.332998,
#         'lng': -73.26751,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.332998,
#           'lng': -73.26751}],
#         'distance': 95479,
#         'postalCode': 'J3A 1B6',
#         'cc': 'CA',
#         'city': 'Saint-Jean-sur-Richelieu',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['935C Boul du Séminaire N',
#          'Saint-Jean-sur-Richelieu QC J3A 1B6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c54265d30f92d7f68dbf2b9-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aa531d3f964a520904720e3',
#        'name': "Speeder & Earl's",
#        'location': {'address': '400 Pine St',
#         'crossStreet': 'at Howard St',
#         'lat': 44.46784879095644,
#         'lng': -73.21492652599818,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.46784879095644,
#           'lng': -73.21492652599818},
#          {'label': 'entrance', 'lat': 44.467901, 'lng': -73.214876}],
#         'distance': 939,
#         'postalCode': '05401',
#         'cc': 'US',
#         'city': 'Burlington',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['400 Pine St (at Howard St)',
#          'Burlington, VT 05401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aa531d3f964a520904720e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b6f2fff2b274a003773b004',
#        'name': '9 Mile Coffee',
#        'location': {'lat': 43.835596,
#         'lng': -73.761841,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.835596,
#           'lng': -73.761841}],
#         'distance': 83705,
#         'postalCode': '12870',
#         'cc': 'US',
#         'city': 'Schroon Lake',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Schroon Lake, NY 12870', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b6f2fff2b274a003773b004-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5f244c19a6815044c65c8756',
#        'name': 'Starbucks',
#        'location': {'address': '37 N Main St',
#         'lat': 43.610928,
#         'lng': -72.9732,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.610928,
#           'lng': -72.9732}],
#         'distance': 98207,
#         'postalCode': '05701',
#         'cc': 'US',
#         'city': 'Rutland',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['37 N Main St',
#          'Rutland, VT 05701',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5f244c19a6815044c65c8756-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8d2c36f964a5207ceb32e3',
#        'name': 'UVM Hendersons Cafe',
#        'location': {'address': '590 Main St',
#         'lat': 44.47596268895631,
#         'lng': -73.19653167996194,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.47596268895631,
#           'lng': -73.19653167996194},
#          {'label': 'entrance', 'lat': 44.477247, 'lng': -73.196718}],
#         'distance': 1300,
#         'postalCode': '05405',
#         'cc': 'US',
#         'city': 'Burlington',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['590 Main St',
#          'Burlington, VT 05405',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2001993',
#         'url': 'https://www.grubhub.com/restaurant/uvm-hendersons-cafe-590-main-street-burlington/2001993?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2001993',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8d2c36f964a5207ceb32e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a9ea7e9d48ec10eae86c016',
#        'name': 'Adk Cavu Cafe',
#        'location': {'lat': 44.38036,
#         'lng': -74.203896,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.38036,
#           'lng': -74.203896}],
#         'distance': 79497,
#         'postalCode': '12983',
#         'cc': 'US',
#         'city': 'Saranac Lake',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Saranac Lake, NY 12983', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a9ea7e9d48ec10eae86c016-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5f1706e08f26cb5bd44bf24a',
#        'name': 'Chapter One: Coffee & Tea',
#        'location': {'address': '30 City Hall Pl',
#         'lat': 44.69841,
#         'lng': -73.451727,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.69841,
#           'lng': -73.451727}],
#         'distance': 31154,
#         'postalCode': '12901',
#         'cc': 'US',
#         'city': 'Plattsburgh',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['30 City Hall Pl',
#          'Plattsburgh, NY 12901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5f1706e08f26cb5bd44bf24a-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5762dba1498e3fc2d04a0db5',
#        'name': 'Onyx Tonics',
#        'location': {'address': '126 College St',
#         'crossStreet': 'Saint Paul St',
#         'lat': 44.477073663439164,
#         'lng': -73.2147717973053,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.477073663439164,
#           'lng': -73.2147717973053}],
#         'distance': 179,
#         'postalCode': '05401',
#         'cc': 'US',
#         'city': 'Burlington',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['126 College St (Saint Paul St)',
#          'Burlington, VT 05401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5762dba1498e3fc2d04a0db5-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b630188f964a5204f5d2ae3',
#        'name': 'Dobra Tea',
#        'location': {'address': '80 Church St',
#         'lat': 44.47821303367501,
#         'lng': -73.21249363379556,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.47821303367501,
#           'lng': -73.21249363379556},
#          {'label': 'entrance', 'lat': 44.478096, 'lng': -73.212501}],
#         'distance': 230,
#         'postalCode': '05401',
#         'cc': 'US',
#         'city': 'Burlington',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['80 Church St',
#          'Burlington, VT 05401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'shortName': 'Tea Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b630188f964a5204f5d2ae3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2f48037cc0c9b6c962eb9a',
#        'name': 'Black Cap Coffee',
#        'location': {'address': '144 Main St',
#         'lat': 44.46520211850929,
#         'lng': -72.68460108565243,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.46520211850929,
#           'lng': -72.68460108565243},
#          {'label': 'entrance', 'lat': 44.465202, 'lng': -72.684555}],
#         'distance': 41985,
#         'postalCode': '05672',
#         'cc': 'US',
#         'city': 'Stowe',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['144 Main St',
#          'Stowe, VT 05672',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2f48037cc0c9b6c962eb9a-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce80b76e888f04d01e33f6b',
#        'name': 'Cedar Run Cafe and Bakery',
#        'location': {'address': '2837 NYS Route 73',
#         'lat': 44.25691761119641,
#         'lng': -73.79431549501061,
# ...
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb4a2b05148d13a6abd523b-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c487d7a972c0f47282b2721',
#        'name': 'New Leaf Coffee House',
#        'location': {'address': '2364 Saranac Ave',
#         'lat': 44.291777249178196,
#         'lng': -73.98680065313368,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.291777249178196,
#           'lng': -73.98680065313368}],
#         'distance': 64898,
#         'postalCode': '12946',
#         'cc': 'US',
#         'city': 'Lake Placid',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['2364 Saranac Ave',
#          'Lake Placid, NY 12946',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c487d7a972c0f47282b2721-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c79247ba8683704226b0f4d',
#        'name': 'Tim Hortons',
#        'location': {'address': '916 Rue Douglas',
#         'crossStreet': 'Douglas',
#         'lat': 45.332096560001276,
#         'lng': -73.28499846160412,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.332096560001276,
#           'lng': -73.28499846160412}],
#         'distance': 95451,
#         'postalCode': 'J3A 1V1',
#         'cc': 'CA',
#         'city': 'Saint-Jean-sur-Richelieu',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['916 Rue Douglas (Douglas)',
#          'Saint-Jean-sur-Richelieu QC J3A 1V1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c79247ba8683704226b0f4d-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '558032ac498e4c12b2b65604',
#        'name': 'Stowe Street Cafe',
#        'location': {'address': '29 Stowe St',
#         'lat': 44.338214,
#         'lng': -72.755197,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.338214,
#           'lng': -72.755197},
#          {'label': 'entrance', 'lat': 44.338357, 'lng': -72.75538}],
#         'distance': 39505,
#         'postalCode': '05676',
#         'cc': 'US',
#         'city': 'Waterbury',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['29 Stowe St',
#          'Waterbury, VT 05676',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-558032ac498e4c12b2b65604-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50d71ebde4b05cc5dec3f9cf',
#        'name': 'Newport Natural Cafe',
#        'location': {'address': '194 Main St',
#         'lat': 44.93566874011709,
#         'lng': -72.20970209613355,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.93566874011709,
#           'lng': -72.20970209613355}],
#         'distance': 94424,
#         'postalCode': '05855',
#         'cc': 'US',
#         'city': 'Newport',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['194 Main St',
#          'Newport, VT 05855',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50d71ebde4b05cc5dec3f9cf-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f44356119836ed00192e389',
#        'name': "Nancy's Village Cafe",
#        'location': {'address': '364 W Main St',
#         'lat': 44.848795,
#         'lng': -74.294933,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.848795,
#           'lng': -74.294933}],
#         'distance': 95184,
#         'postalCode': '12953',
#         'cc': 'US',
#         'city': 'Malone',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['364 W Main St',
#          'Malone, NY 12953',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f44356119836ed00192e389-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5f78994dc7309a64266fb721',
#        'name': 'Pk Coffee',
#        'location': {'address': '40 Foundry St',
#         'lat': 44.337301,
#         'lng': -72.754454,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.337301,
#           'lng': -72.754454}],
#         'distance': 39599,
#         'postalCode': '05676',
#         'cc': 'US',
#         'city': 'Waterbury',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['40 Foundry St',
#          'Waterbury, VT 05676',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5f78994dc7309a64266fb721-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcb26c5cc8cd13a57bdbecf',
#        'name': 'Blue Moon Cafe',
#        'location': {'address': '46 Main St',
#         'lat': 44.32594877822094,
#         'lng': -74.13186865685155,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.32594877822094,
#           'lng': -74.13186865685155},
#          {'label': 'entrance', 'lat': 44.325987, 'lng': -74.131843}],
#         'distance': 74975,
#         'postalCode': '12983',
#         'cc': 'US',
#         'city': 'Saranac Lake',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['46 Main St',
#          'Saranac Lake, NY 12983',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bcb26c5cc8cd13a57bdbecf-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '549df3de498ee641a5373f2c',
#        'name': 'Tight Squeeze Coffee Shop',
#        'location': {'address': '125 College St',
#         'lat': 44.47712551069073,
#         'lng': -73.21504572137148,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.47712551069073,
#           'lng': -73.21504572137148}],
#         'distance': 201,
#         'postalCode': '05401',
#         'cc': 'US',
#         'city': 'Burlington',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['125 College St',
#          'Burlington, VT 05401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2285400',
#         'url': 'https://www.grubhub.com/restaurant/tight-squeeze-coffee-shop-125-college-street-burlington/2285400?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2285400',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-549df3de498ee641a5373f2c-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5da8b18e0892280008d3af15',
#        'name': 'Bristol Cliffs Cafe',
#        'location': {'lat': 44.133198,
#         'lng': -73.077736,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.133198,
#           'lng': -73.077736}],
#         'distance': 39667,
#         'postalCode': '05443',
#         'cc': 'US',
#         'city': 'Bristol',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['Bristol, VT 05443', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5da8b18e0892280008d3af15-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d8e430596cd770008612fd4',
#        'name': 'Royal Oak Coffee',
#        'location': {'address': '30 Seymour St',
#         'lat': 44.017718,
#         'lng': -73.169052,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.017718,
#           'lng': -73.169052}],
#         'distance': 51152,
#         'postalCode': '05753',
#         'cc': 'US',
#         'city': 'Middlebury',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['30 Seymour St',
#          'Middlebury, VT 05753',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d8e430596cd770008612fd4-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50352585e4b04e46b7be109a',
#        'name': 'Miscela Caffé',
#        'location': {'address': '292 rue Champlain',
#         'lat': 45.31018890934571,
#         'lng': -73.25222935879208,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.31018890934571,
#           'lng': -73.25222935879208}],
#         'distance': 92894,
#         'postalCode': 'J3B 6W1',
#         'cc': 'CA',
#         'city': 'Saint-Jean-sur-Richelieu',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['292 rue Champlain',
#          'Saint-Jean-sur-Richelieu QC J3B 6W1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '91672797'}},
#       'referralId': 'e-0-50352585e4b04e46b7be109a-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b33b303f964a5203f1d25e3',
#        'name': '3 Squares Cafe',
#        'location': {'address': '221 Main St',
#         'lat': 44.167511835896285,
#         'lng': -73.2526762332949,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.167511835896285,
#           'lng': -73.2526762332949},
#          {'label': 'entrance', 'lat': 44.167478, 'lng': -73.252556}],
#         'distance': 34504,
#         'postalCode': '05491',
#         'cc': 'US',
#         'city': 'Vergennes',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['221 Main St',
#          'Vergennes, VT 05491',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b33b303f964a5203f1d25e3-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57128fc1498e79efe74921cf',
#        'name': 'PK Coffee',
#        'location': {'address': '1880 Mountain Rd',
#         'lat': 44.474433844591935,
#         'lng': -72.71447972604152,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.474433844591935,
#           'lng': -72.71447972604152}],
#         'distance': 39591,
#         'cc': 'US',
#         'city': 'Stowe',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['1880 Mountain Rd',
#          'Stowe, VT',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57128fc1498e79efe74921cf-99'}]}]}}

# %%
venues_vt = results_vt['response']['groups'][0]['items']
    
nearby_venues_vt = json_normalize(venues_vt) # flatten JSON
# Out:
# <ipython-input-22-c3685445dbe3>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues_vt = json_normalize(venues_vt) # flatten JSON

# %%
# filter columns
filtered_columns_vt = ['venue.name', 'venue.categories', 'venue.location.city', 'venue.location.state', 'venue.location.lat', 'venue.location.lng']
nearby_venues_vt =nearby_venues_vt.loc[:, filtered_columns_vt]

# filter the category for each row
nearby_venues_vt['venue.categories'] = nearby_venues_vt.apply(get_category_type, axis=1)

# clean columns
nearby_venues_vt.columns = [col.split(".")[-1] for col in nearby_venues_vt.columns]

nearby_venues_vt.head()
# Out:
#                               name   categories                      city  \
# 0  UVM Medical Center Harvest Café         Café                Burlington
# 1                      Tim Hortons  Coffee Shop  Saint-Bernard-de-Lacolle
# 2                        Starbucks  Coffee Shop            Essex Junction
# 3                        Starbucks  Coffee Shop          South Burlington
# 4       Maplefields Mobile. US Ave  Coffee Shop               Plattsburgh
#
#   state        lat        lng
# 0    VT  44.480187 -73.195263
# 1    QC  45.067424 -73.457205
# 2    VT  44.504437 -73.138335
# 3    VT  44.468840 -73.178050
# 4    NY  44.682333 -73.447903

# %% [markdown]
# New Hampshire:

# %%
address = 'Concord, New Hampshire'

geolocator = Nominatim(user_agent="nh_explorer")
location = geolocator.geocode(address)
latitude_nh = location.latitude
longitude_nh = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude_nh, longitude_nh))
# Out:
# The geograpical coordinate of Toronto are 43.207178, -71.537476.

# %%
LIMIT = 500 # limit of number of venues returned by Foursquare API



radius = 100000 # define radius

# create URL
url_nh = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&sortByPopularity=1&categoryId=4bf58dd8d48988d1e0931735,4bf58dd8d48988d16d941735'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude_nh, 
    longitude_nh,
    radius,
    LIMIT)
url_nh # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=C4MNDL1LR5W55W5YGR2VTH3WFM40JKALTLRJWHAA153YWUFS&client_secret=IMMVE4P4CMKN0PVUHTRX3NGRFMMN1APMJICKBIC0UXCSZDKT&v=20180605&ll=43.207178,-71.537476&radius=100000&limit=500&sortByPopularity=1&categoryId=4bf58dd8d48988d1e0931735,4bf58dd8d48988d16d941735'

# %%
results_nh = requests.get(url_nh).json()
results_nh
# Out:
# {'meta': {'code': 200, 'requestId': '60e872b31b9ba75c28d1afd7'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Concord',
#   'headerFullLocation': 'Concord',
#   'headerLocationGranularity': 'city',
#   'query': 'coffee shop',
#   'totalResults': 128,
#   'suggestedBounds': {'ne': {'lat': 44.107178900000896,
#     'lng': -70.30501390987558},
#    'sw': {'lat': 42.3071770999991, 'lng': -72.76993809012441}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '60df28e60e501b1ba8a7cbdf',
#        'name': 'Foothills Cafe',
#        'location': {'address': '25 Main Street',
#         'lat': 43.806166,
#         'lng': -71.438152,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.806166,
#           'lng': -71.438152}],
#         'distance': 67159,
#         'postalCode': '03227',
#         'cc': 'US',
#         'city': 'Center Sandwich',
#         'state': 'NH',
#         'country': 'United States',
#         'formattedAddress': ['25 Main Street',
#          'Center Sandwich, NH 03227',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-60df28e60e501b1ba8a7cbdf-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58a5d1e29465dd3f9e60712e',
#        'name': 'WFM Coffee Bar',
#        'location': {'address': '160 Littleton Rd',
#         'lat': 42.5688067258927,
#         'lng': -71.4210503575312,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.5688067258927,
#           'lng': -71.4210503575312}],
#         'distance': 71694,
#         'postalCode': '01886',
#         'cc': 'US',
#         'city': 'Westford',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['160 Littleton Rd',
#          'Westford, MA 01886',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58a5d1e29465dd3f9e60712e-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7ad063f964a520373e2fe3',
#        'name': "Heav'nly Donuts",
#        'location': {'address': '126 Merrimack St',
#         'crossStreet': 'at Myona St',
#         'lat': 42.731003470097406,
#         'lng': -71.13755201553215,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.731003470097406,
#           'lng': -71.13755201553215},
#          {'label': 'entrance', 'lat': 42.730795, 'lng': -71.137711}],
#         'distance': 62216,
#         'postalCode': '01844',
#         'cc': 'US',
#         'city': 'Methuen',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['126 Merrimack St (at Myona St)',
#          'Methuen, MA 01844',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7ad063f964a520373e2fe3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fc9457ad4f24895b4467691',
#        'name': 'Starbucks',
#        'location': {'address': '93 S River Rd',
#         'crossStreet': 'at Kilton Rd',
#         'lat': 42.95661708,
#         'lng': -71.47812462,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.95661708,
#           'lng': -71.47812462}],
#         'distance': 28306,
#         'postalCode': '03110',
#         'cc': 'US',
#         'city': 'Bedford',
#         'state': 'NH',
#         'country': 'United States',
#         'formattedAddress': ['93 S River Rd (at Kilton Rd)',
#          'Bedford, NH 03110',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fc9457ad4f24895b4467691-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49f5c74cf964a520b66b1fe3',
#        'name': 'Cafe Rustica',
#        'location': {'address': '356 Beacon St',
#         'crossStreet': 'Forest St',
#         'lat': 42.38578293902425,
#         'lng': -71.11568769820023,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.38578293902425,
#           'lng': -71.11568769820023},
#          {'label': 'entrance', 'lat': 42.385685, 'lng': -71.115649}],
#         'distance': 97711,
#         'postalCode': '02143',
#         'cc': 'US',
#         'city': 'Somerville',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['356 Beacon St (Forest St)',
#          'Somerville, MA 02143',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2509666',
#         'url': 'https://www.grubhub.com/restaurant/cafe-rustica-356-beacon-st-somerville/2509666?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2509666',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-49f5c74cf964a520b66b1fe3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a8d7b5d8fb09e0adce9619d',
#        'name': 'Starbucks',
#        'location': {'address': '2105 Commonwealth Ave',
#         'crossStreet': 'Lexington St.',
#         'lat': 42.348277906651276,
#         'lng': -71.2476202322916,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.348277906651276,
#           'lng': -71.2476202322916}],
#         'distance': 98501,
#         'postalCode': '02466',
#         'cc': 'US',
#         'neighborhood': 'Auburndale',
#         'city': 'Auburndale',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['2105 Commonwealth Ave (Lexington St.)',
#          'Auburndale, MA 02466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a8d7b5d8fb09e0adce9619d-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3aa9c5f964a520386c25e3',
#        'name': 'Starbucks',
#        'location': {'address': '1111 S Willow St',
#         'crossStreet': 'at Grail Cir',
#         'lat': 42.96019197,
#         'lng': -71.43833806,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.96019197,
#           'lng': -71.43833806},
#          {'label': 'entrance', 'lat': 42.959821, 'lng': -71.438515}],
#         'distance': 28651,
#         'postalCode': '03103',
#         'cc': 'US',
#         'city': 'Manchester',
#         'state': 'NH',
#         'country': 'United States',
#         'formattedAddress': ['1111 S Willow St (at Grail Cir)',
#          'Manchester, NH 03103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3aa9c5f964a520386c25e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '530aac3c498eefae4857e167',
#        'name': 'Pressed Cafe',
#        'location': {'address': '108 Spit Brook Rd',
#         'lat': 42.70844527195605,
#         'lng': -71.45792615223996,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.70844527195605,
#           'lng': -71.45792615223996}],
#         'distance': 55895,
#         'postalCode': '03062',
#         'cc': 'US',
#         'neighborhood': 'Southwest Nashua',
#         'city': 'Nashua',
#         'state': 'NH',
#         'country': 'United States',
#         'formattedAddress': ['108 Spit Brook Rd',
#          'Nashua, NH 03062',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-530aac3c498eefae4857e167-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58b70ee8f8408553bbd4d859',
#        'name': 'Starbucks',
#        'location': {'address': '399 Revolution Dr',
#         'lat': 42.391569784937026,
#         'lng': -71.0785556171418,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.391569784937026,
#           'lng': -71.0785556171418}],
#         'distance': 98225,
#         'postalCode': '02145',
#         'cc': 'US',
#         'city': 'Somerville',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['399 Revolution Dr',
#          'Somerville, MA 02145',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58b70ee8f8408553bbd4d859-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '554f44c9498e845219e1488b',
#        'name': 'Pop Donuts',
#        'location': {'address': '297 Andover St',
#         'crossStreet': 'Winthrop Ave',
#         'lat': 42.69477926372494,
#         'lng': -71.15754858625249,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.69477926372494,
#           'lng': -71.15754858625249}],
#         'distance': 64898,
#         'postalCode': '01843',
#         'cc': 'US',
#         'city': 'Lawrence',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['297 Andover St (Winthrop Ave)',
#          'Lawrence, MA 01843',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-554f44c9498e845219e1488b-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59e9f56560255e3d6cda4d13',
#        'name': 'Caffè Nero',
#        'location': {'address': '375 Assembly Row',
#         'lat': 42.39294092959071,
#         'lng': -71.07873771807803,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.39294092959071,
#           'lng': -71.07873771807803},
#          {'label': 'entrance', 'lat': 42.39299, 'lng': -71.07866}],
#         'distance': 98078,
#         'postalCode': '02145',
#         'cc': 'US',
#         'city': 'Somerville',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['375 Assembly Row',
#          'Somerville, MA 02145',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59e9f56560255e3d6cda4d13-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e6d1fce091a4234340ed316',
#        'name': '3 Little Figs',
#        'location': {'address': '278 Highland Ave',
#         'crossStreet': 'btwn Cedar & Eastman',
#         'lat': 42.3919899632366,
#         'lng': -71.11189026934323,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.3919899632366,
#           'lng': -71.11189026934323}],
#         'distance': 97175,
#         'postalCode': '02143',
#         'cc': 'US',
#         'city': 'Somerville',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['278 Highland Ave (btwn Cedar & Eastman)',
#          'Somerville, MA 02143',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e6d1fce091a4234340ed316-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57f3cfdc498ede68f909b6cc',
#        'name': 'Tatte Bakery & Cafe',
#        'location': {'address': '1288 Massachusetts Ave',
#         'lat': 42.372794996708876,
#         'lng': -71.11696614549051,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.372794996708876,
#           'lng': -71.11696614549051},
#          {'label': 'entrance', 'lat': 42.372699, 'lng': -71.116994}],
#         'distance': 99031,
#         'postalCode': '02138',
#         'cc': 'US',
#         'city': 'Cambridge',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['1288 Massachusetts Ave',
#          'Cambridge, MA 02138',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57f3cfdc498ede68f909b6cc-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '517019e6498e802b4295d04b',
#        'name': "Heav'nly Donuts",
#        'location': {'address': '40 Main St.',
#         'lat': 42.70484550209485,
#         'lng': -71.13295749842706,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.70484550209485,
#           'lng': -71.13295749842706},
#          {'label': 'entrance', 'lat': 42.704865, 'lng': -71.132984}],
#         'distance': 64908,
#         'cc': 'US',
#         'city': 'North Andover',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['40 Main St.',
#          'North Andover, MA',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-517019e6498e802b4295d04b-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5aa687e80a464d2cf7ca54a8',
#        'name': 'Starbucks',
#        'location': {'address': '450 Paradise Rd',
#         'lat': 42.482338,
#         'lng': -70.9033,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.482338,
#           'lng': -70.9033}],
#         'distance': 95862,
#         'postalCode': '01907',
#         'cc': 'US',
#         'city': 'Swampscott',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['450 Paradise Rd',
#          'Swampscott, MA 01907',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5aa687e80a464d2cf7ca54a8-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58c1842a65be585bf1a9315a',
#        'name': 'Intelligentsia Coffee',
#        'location': {'address': '810 Mount Auburn St',
#         'lat': 42.374616459212696,
#         'lng': -71.1507418030885,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.374616459212696,
#           'lng': -71.1507418030885}],
#         'distance': 97916,
#         'postalCode': '02472',
#         'cc': 'US',
#         'city': 'Watertown',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['810 Mount Auburn St',
#          'Watertown, MA 02472',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58c1842a65be585bf1a9315a-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59de096e295513311aa5213e',
#        'name': 'Starbucks',
#        'location': {'address': '360 Alfred St',
#         'lat': 43.48309530965138,
#         'lng': -70.4722457232109,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.48309530965138,
#           'lng': -70.4722457232109},
#          {'label': 'entrance', 'lat': 43.483053, 'lng': -70.472411}],
#         'distance': 91541,
#         'postalCode': '04005',
#         'cc': 'US',
#         'city': 'Biddeford',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['360 Alfred St',
#          'Biddeford, ME 04005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59de096e295513311aa5213e-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a6ca55a4f0e582cd110b365',
#        'name': 'Caffè Nero',
#        'location': {'address': '75 Middlesex Tpke',
#         'crossStreet': 'Mall Road',
#         'lat': 42.48298564615364,
#         'lng': -71.21371682726551,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.48298564615364,
#           'lng': -71.21371682726551}],
#         'distance': 84836,
#         'postalCode': '01803',
#         'cc': 'US',
#         'city': 'Burlington',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['75 Middlesex Tpke (Mall Road)',
#          'Burlington, MA 01803',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a6ca55a4f0e582cd110b365-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5957a5d459fe5c1d1e77681b',
#        'name': 'Broadsheet Coffee Roasters',
#        'location': {'address': '100 Kirkland St',
#         'crossStreet': 'Line Street',
#         'lat': 42.37803942424761,
#         'lng': -71.10727511477586,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.37803942424761,
#           'lng': -71.10727511477586}],
#         'distance': 98762,
#         'postalCode': '02138',
#         'cc': 'US',
#         'neighborhood': 'Mid-Cambridge',
#         'city': 'Cambridge',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['100 Kirkland St (Line Street)',
#          'Cambridge, MA 02138',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5957a5d459fe5c1d1e77681b-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b4df6abd03360002cca853d',
#        'name': 'Time & Tide Coffee',
#        'location': {'address': '35 Main St',
#         'lat': 43.492582817520855,
#         'lng': -70.45089904142667,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.492582817520855,
#           'lng': -70.45089904142667}],
#         'distance': 93517,
#         'postalCode': '04005',
#         'cc': 'US',
#         'city': 'Biddeford',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['35 Main St',
#          'Biddeford, ME 04005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b4df6abd03360002cca853d-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '528cf4af498e8f21d55a3f45',
#        'name': 'Kickstand Café',
#        'location': {'address': '594 Massachusetts Ave',
#         'crossStreet': 'Swan Place',
#         'lat': 42.414703,
#         'lng': -71.152755,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.414703,
#           'lng': -71.152755}],
#         'distance': 93644,
#         'postalCode': '02476',
#         'cc': 'US',
#         'city': 'Arlington',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['594 Massachusetts Ave (Swan Place)',
#          'Arlington, MA 02476',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-528cf4af498e8f21d55a3f45-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bebe446b3352d7f3fee56d2',
#        'name': 'The Grind Rail Trail Cafe',
#        'location': {'address': '5 W Broadway',
#         'lat': 42.8805267278396,
#         'lng': -71.32699464545888,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.8805267278396,
#           'lng': -71.32699464545888},
#          {'label': 'entrance', 'lat': 42.880741, 'lng': -71.327037}],
#         'distance': 40192,
#         'postalCode': '03038',
#         'cc': 'US',
#         'city': 'Derry',
#         'state': 'NH',
#         'country': 'United States',
#         'formattedAddress': ['5 W Broadway',
#          'Derry, NH 03038',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '84012235'}},
#       'referralId': 'e-0-4bebe446b3352d7f3fee56d2-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a906e3cf964a520d11720e3',
#        'name': 'Main Streets Market & Cafe',
#        'location': {'address': '42 Main St',
#         'crossStreet': 'Walden St',
#         'lat': 42.45993225079906,
#         'lng': -71.35021611969538,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.45993225079906,
#           'lng': -71.35021611969538},
#          {'label': 'entrance', 'lat': 42.460076, 'lng': -71.350305}],
#         'distance': 84575,
#         'postalCode': '01742',
#         'cc': 'US',
#         'city': 'Concord',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['42 Main St (Walden St)',
#          'Concord, MA 01742',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2746876',
#         'url': 'https://www.grubhub.com/restaurant/main-streets-market--cafe-42-main-st-concord/2746876?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2746876',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a906e3cf964a520d11720e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d57df35d1a08cfac4a108ba',
#        'name': 'Brothers Brew',
#        'location': {'address': '27 Main St',
#         'lat': 42.65833698123199,
#         'lng': -70.61850102408891,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.65833698123199,
#           'lng': -70.61850102408891},
#          {'label': 'entrance', 'lat': 42.658368, 'lng': -70.618496}],
#         'distance': 96655,
#         'postalCode': '01966',
#         'cc': 'US',
#         'city': 'Rockport',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['27 Main St',
#          'Rockport, MA 01966',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '56481006'}},
#       'referralId': 'e-0-4d57df35d1a08cfac4a108ba-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57b9ad77498e5394bbd8e9e3',
#        'name': 'Starbucks',
#        'location': {'address': '1 Mystic View Road',
#         'lat': 42.399003,
#         'lng': -71.07186,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.399003,
#           'lng': -71.07186}],
#         'distance': 97671,
#         'postalCode': '02149',
#         'cc': 'US',
#         'city': 'Everett',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['1 Mystic View Road',
#          'Everett, MA 02149',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57b9ad77498e5394bbd8e9e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b2a459273fe25002c2b2a29',
#        'name': 'Revival Cafe',
#        'location': {'address': '125 Cambridgepark Dr',
#         'lat': 42.39525582204473,
#         'lng': -71.14589955921667,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.39525582204473,
#           'lng': -71.14589955921667}],
#         'distance': 95873,
#         'postalCode': '02140',
#         'cc': 'US',
#         'neighborhood': 'North Cambridge',
#         'city': 'Cambridge',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['125 Cambridgepark Dr',
#          'Cambridge, MA 02140',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2443021',
#         'url': 'https://www.grubhub.com/restaurant/revival-cafe--kitchen-125-cambridge-park-dr-cambridge/2443021?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2443021',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b2a459273fe25002c2b2a29-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53935b52498e4754a4aa8ced',
#        'name': 'Kung Fu Tea',
#        'location': {'address': '3 Pleasant St',
#         'lat': 42.42667864748606,
#         'lng': -71.06737891595594,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.42667864748606,
#           'lng': -71.06737891595594}],
#         'distance': 94985,
#         'postalCode': '02148',
#         'cc': 'US',
#         'city': 'Malden',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['3 Pleasant St',
#          'Malden, MA 02148',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'shortName': 'Tea Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1719086',
#         'url': 'https://www.grubhub.com/restaurant/kung-fu-tea-3-pleasant-st-malden/1719086?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1719086',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53935b52498e4754a4aa8ced-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55be4a87498eb4327da7a941',
#        'name': 'Nine Bar Espresso',
#        'location': {'address': '11 Holland St',
#         'lat': 42.397095,
#         'lng': -71.122859,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.397095,
#           'lng': -71.122859},
#          {'label': 'entrance', 'lat': 42.397141, 'lng': -71.122873}],
#         'distance': 96325,
#         'postalCode': '02144',
#         'cc': 'US',
#         'city': 'Somerville',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['11 Holland St',
#          'Somerville, MA 02144',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55be4a87498eb4327da7a941-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '60747c1e0729f64944faa1f9',
#        'name': 'Starbucks',
#        'location': {'address': '57 Central Street Unit A',
#         'lat': 42.777914,
#         'lng': -71.229349,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.777914,
#           'lng': -71.229349}],
#         'distance': 53970,
#         'postalCode': '03079',
#         'cc': 'US',
#         'city': 'Salem',
#         'state': 'NH',
#         'country': 'United States',
#         'formattedAddress': ['57 Central Street Unit A',
#          'Salem, NH 03079',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-60747c1e0729f64944faa1f9-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae5d164f964a52043a221e3',
#        'name': "Gail Ann's Coffee Shop",
#        'location': {'address': '10 Medford St',
#         'lat': 42.41497608599653,
#         'lng': -71.15093800751343,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.41497608599653,
#           'lng': -71.15093800751343},
#          {'label': 'entrance', 'lat': 42.415043, 'lng': -71.151025}],
#         'distance': 93665,
#         'postalCode': '02474',
#         'cc': 'US',
#         'city': 'Arlington',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['10 Medford St',
#          'Arlington, MA 02474',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae5d164f964a52043a221e3-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcf2d8c77b29c7463898882',
#        'name': 'Putney Food Co-op',
#        'location': {'address': '8 Carol Brown Way',
#         'crossStreet': 'at corner of Route 5',
#         'lat': 42.96794753646104,
#         'lng': -72.52317517402201,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.96794753646104,
#           'lng': -72.52317517402201},
#          {'label': 'entrance', 'lat': 42.967923, 'lng': -72.523102}],
#         'distance': 84443,
#         'postalCode': '05346',
#         'cc': 'US',
#         'city': 'Putney',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['8 Carol Brown Way (at corner of Route 5)',
#          'Putney, VT 05346',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bcf2d8c77b29c7463898882-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57a4954f498eabe3129ea0b1',
#        'name': 'The Greenery Cafe',
#        'location': {'address': '369 Main St',
#         'lat': 43.25432284485319,
#         'lng': -70.60029841556144,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.25432284485319,
#           'lng': -70.60029841556144}],
#         'distance': 76192,
#         'postalCode': '03907',
#         'cc': 'US',
#         'city': 'Ogunquit',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['369 Main St',
#          'Ogunquit, ME 03907',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57a4954f498eabe3129ea0b1-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a9ab276f964a5203d3220e3',
#        'name': 'Bloc 11 Cafe',
#        'location': {'address': '11 Bow St',
#         'crossStreet': 'at Walnut St.',
#         'lat': 42.380805620178606,
#         'lng': -71.09692157048192,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.380805620178606,
#           'lng': -71.09692157048192}],
#         'distance': 98779,
#         'postalCode': '02143',
#         'cc': 'US',
#         'city': 'Somerville',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['11 Bow St (at Walnut St.)',
#          'Somerville, MA 02143',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2438214',
#         'url': 'https://www.grubhub.com/restaurant/bloc-cafe-11-bow-st-somerville/2438214?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2438214',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '104226153'}},
#       'referralId': 'e-0-4a9ab276f964a5203d3220e3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b649a1f5a2c91002ca5d091',
#        'name': 'Common Man Joe',
#        'location': {'lat': 43.110722,
#         'lng': -71.475647,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.110722,
#           'lng': -71.475647}],
#         'distance': 11853,
#         'postalCode': '03106',
#         'cc': 'US',
#         'city': 'Hooksett',
#         'state': 'NH',
#         'country': 'United States',
#         'formattedAddress': ['Hooksett, NH 03106', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b649a1f5a2c91002ca5d091-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b094a6bf964a520491523e3',
#        'name': 'Jaho Coffee Roaster & Wine Bar',
#        'location': {'address': '197 Derby St',
#         'crossStreet': 'at Wharf St.',
#         'lat': 42.52088845035255,
#         'lng': -70.88823148996529,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.52088845035255,
#           'lng': -70.88823148996529}],
#         'distance': 92965,
#         'postalCode': '01970',
#         'cc': 'US',
#         'city': 'Salem',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['197 Derby St (at Wharf St.)',
#          'Salem, MA 01970',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b094a6bf964a520491523e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5cf050a333e118002c6bb0d3',
#        'name': 'Caffè Nero',
#        'location': {'address': '1872 Massachusetts Ave',
#         'lat': 42.388001,
#         'lng': -71.119652,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.388001,
#           'lng': -71.119652}],
#         'distance': 97366,
#         'postalCode': '02140',
#         'cc': 'US',
#         'city': 'Cambridge',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['1872 Massachusetts Ave',
#          'Cambridge, MA 02140',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5cf050a333e118002c6bb0d3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1147e6f964a520af7923e3',
#        'name': "Brew'd Awakening Coffeehaus",
#        'location': {'address': '67 Market St',
#         'lat': 42.644472282291304,
#         'lng': -71.30976243172042,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.644472282291304,
#           'lng': -71.30976243172042},
#          {'label': 'entrance', 'lat': 42.64451, 'lng': -71.30986}],
#         'distance': 65331,
#         'postalCode': '01852',
#         'cc': 'US',
#         'city': 'Lowell',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['67 Market St',
#          'Lowell, MA 01852',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1147e6f964a520af7923e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be5740ecf200f472e31133c',
#        'name': "St Anthony's Bakery",
#        'location': {'address': 'Water Street',
#         'lat': 42.98199476162322,
#         'lng': -70.94974268093208,
#         'labeledLatLngs': [{'label': 'display',
# ...
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1618697',
#         'url': 'https://www.grubhub.com/restaurant/the-bridge-cafe-1117-elm-street-manchester/1618697?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1618697',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '42895633'}},
#       'referralId': 'e-0-4afad808f964a520f71822e3-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd46f5867adf04d16412791',
#        'name': 'Kaffee Vonsolln',
#        'location': {'address': '79 Daniel St',
#         'lat': 43.07743074635966,
#         'lng': -70.75605830600541,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.07743074635966,
#           'lng': -70.75605830600541},
#          {'label': 'entrance', 'lat': 43.077386, 'lng': -70.755979}],
#         'distance': 65092,
#         'postalCode': '03801',
#         'cc': 'US',
#         'city': 'Portsmouth',
#         'state': 'NH',
#         'country': 'United States',
#         'formattedAddress': ['79 Daniel St',
#          'Portsmouth, NH 03801',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1619136',
#         'url': 'https://www.grubhub.com/restaurant/kaffee-vonsolln-79-daniel-street-portsmouth/1619136?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1619136',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd46f5867adf04d16412791-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5213e5f964a520146627e3',
#        'name': "Mocha Joe's Cafe",
#        'location': {'address': '82 Main St',
#         'lat': 42.85197306959865,
#         'lng': -72.55793317152269,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.85197306959865,
#           'lng': -72.55793317152269},
#          {'label': 'entrance', 'lat': 42.85198, 'lng': -72.557989}],
#         'distance': 91971,
#         'postalCode': '05301',
#         'cc': 'US',
#         'city': 'Brattleboro',
#         'state': 'VT',
#         'country': 'United States',
#         'formattedAddress': ['82 Main St',
#          'Brattleboro, VT 05301',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '432257886'}},
#       'referralId': 'e-0-4b5213e5f964a520146627e3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9ceb8bf964a5206a8236e3',
#        'name': 'Starbucks',
#        'location': {'address': 'Baggage Claim',
#         'crossStreet': 'MHT Airport',
#         'lat': 42.92791265323513,
#         'lng': -71.4374828338623,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.92791265323513,
#           'lng': -71.4374828338623}],
#         'distance': 32133,
#         'postalCode': '03103',
#         'cc': 'US',
#         'city': 'Manchester',
#         'state': 'NH',
#         'country': 'United States',
#         'formattedAddress': ['Baggage Claim (MHT Airport)',
#          'Manchester, NH 03103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9ceb8bf964a5206a8236e3-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6d93c7f964a520ad7d2ce3',
#        'name': 'Caffe Kilim',
#        'location': {'address': '163 Islington St',
#         'crossStreet': 'at Summer Street',
#         'lat': 43.074417604576695,
#         'lng': -70.76372909748949,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.074417604576695,
#           'lng': -70.76372909748949},
#          {'label': 'entrance', 'lat': 43.074434, 'lng': -70.763845}],
#         'distance': 64562,
#         'postalCode': '03801',
#         'cc': 'US',
#         'city': 'Portsmouth',
#         'state': 'NH',
#         'country': 'United States',
#         'formattedAddress': ['163 Islington St (at Summer Street)',
#          'Portsmouth, NH 03801',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1850343',
#         'url': 'https://www.grubhub.com/restaurant/caffe-kilim-and-market-163-islington-street-portsmouth/1850343?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1850343',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6d93c7f964a520ad7d2ce3-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5139f1d1e4b02c889a6abbd3',
#        'name': 'Elements: Books Coffee Beer',
#        'location': {'address': '265 Main St',
#         'lat': 43.49406009659992,
#         'lng': -70.4580171153537,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.49406009659992,
#           'lng': -70.4580171153537}],
#         'distance': 93031,
#         'postalCode': '04005',
#         'cc': 'US',
#         'city': 'Biddeford',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['265 Main St',
#          'Biddeford, ME 04005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '179908181'}},
#       'referralId': 'e-0-5139f1d1e4b02c889a6abbd3-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c6e8b1a1cbeb71328e59e3c',
#        'name': 'The Riverhouse Cafe',
#        'location': {'address': '123 Union Sq',
#         'crossStreet': 'On the oval',
#         'lat': 42.835985167177036,
#         'lng': -71.64977977000486,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.835985167177036,
#           'lng': -71.64977977000486},
#          {'label': 'entrance', 'lat': 42.8361, 'lng': -71.649772}],
#         'distance': 42319,
#         'postalCode': '03055',
#         'cc': 'US',
#         'city': 'Milford',
#         'state': 'NH',
#         'country': 'United States',
#         'formattedAddress': ['123 Union Sq (On the oval)',
#          'Milford, NH 03055',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '51322813'}},
#       'referralId': 'e-0-4c6e8b1a1cbeb71328e59e3c-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '520e4c8011d2b1ca57188930',
#        'name': 'White Heron Tea & Coffee Community',
#        'location': {'address': '601 Islington St',
#         'lat': 43.071083269957505,
#         'lng': -70.77074921425023,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.071083269957505,
#           'lng': -70.77074921425023}],
#         'distance': 64096,
#         'postalCode': '03801',
#         'cc': 'US',
#         'city': 'Portsmouth',
#         'state': 'NH',
#         'country': 'United States',
#         'formattedAddress': ['601 Islington St',
#          'Portsmouth, NH 03801',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1620007',
#         'url': 'https://www.grubhub.com/restaurant/white-heron-tea--coffee-601-islington-street-portsmouth/1620007?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1620007',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-520e4c8011d2b1ca57188930-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5031366be4b0c5661dbc75ad',
#        'name': 'Backyard Coffeehouse & Eatery',
#        'location': {'address': '178 Main St',
#         'lat': 43.247551538095856,
#         'lng': -70.59992683828149,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.247551538095856,
#           'lng': -70.59992683828149}],
#         'distance': 76178,
#         'postalCode': '03907',
#         'cc': 'US',
#         'city': 'Ogunquit',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['178 Main St',
#          'Ogunquit, ME 03907',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5031366be4b0c5661dbc75ad-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a8457baf964a52054fc1fe3',
#        'name': 'The Java Room',
#        'location': {'address': '14 Littleton Rd',
#         'crossStreet': 'Rt 110',
#         'lat': 42.5963970106942,
#         'lng': -71.35461463925364,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.5963970106942,
#           'lng': -71.35461463925364}],
#         'distance': 69607,
#         'postalCode': '01824',
#         'cc': 'US',
#         'city': 'Chelmsford',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['14 Littleton Rd (Rt 110)',
#          'Chelmsford, MA 01824',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a8457baf964a52054fc1fe3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5284d28d11d20524a321c22b',
#        'name': "Lil's",
#        'location': {'address': '7 Wallingford Sq',
#         'lat': 43.08591516917711,
#         'lng': -70.74346197834637,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.08591516917711,
#           'lng': -70.74346197834637}],
#         'distance': 65886,
#         'postalCode': '03904',
#         'cc': 'US',
#         'city': 'Kittery',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['7 Wallingford Sq',
#          'Kittery, ME 03904',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1620976',
#         'url': 'https://www.grubhub.com/restaurant/lils-cafe-7-wallingford-square-kittery/1620976?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1620976',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5284d28d11d20524a321c22b-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52f3c65e11d267260f4cb4e7',
#        'name': 'Capital One Café',
#        'location': {'address': '24 JFK St',
#         'lat': 42.372897901291125,
#         'lng': -71.11967593431473,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.372897901291125,
#           'lng': -71.11967593431473},
#          {'label': 'entrance', 'lat': 42.37302, 'lng': -71.119666}],
#         'distance': 98943,
#         'postalCode': '02138',
#         'cc': 'US',
#         'city': 'Cambridge',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['24 JFK St',
#          'Cambridge, MA 02138',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52f3c65e11d267260f4cb4e7-99'}]}]}}

# %%
venues_nh = results_nh['response']['groups'][0]['items']
    
nearby_venues_nh = json_normalize(venues_nh) # flatten JSON
# Out:
# <ipython-input-27-a5764f285550>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues_nh = json_normalize(venues_nh) # flatten JSON

# %%
# filter columns
filtered_columns_nh = ['venue.name', 'venue.categories', 'venue.location.city', 'venue.location.state', 'venue.location.lat', 'venue.location.lng']
nearby_venues_nh =nearby_venues_nh.loc[:, filtered_columns_nh]

# filter the category for each row
nearby_venues_nh['venue.categories'] = nearby_venues_nh.apply(get_category_type, axis=1)

# clean columns
nearby_venues_nh.columns = [col.split(".")[-1] for col in nearby_venues_nh.columns]

nearby_venues_nh.head()
# Out:
#               name   categories             city state        lat        lng
# 0   Foothills Cafe         Café  Center Sandwich    NH  43.806166 -71.438152
# 1   WFM Coffee Bar  Coffee Shop         Westford    MA  42.568807 -71.421050
# 2  Heav'nly Donuts  Coffee Shop          Methuen    MA  42.731003 -71.137552
# 3        Starbucks  Coffee Shop          Bedford    NH  42.956617 -71.478125
# 4     Cafe Rustica         Café       Somerville    MA  42.385783 -71.115688

# %% [markdown]
# Maine:

# %%
address = 'Augusta, Maine'

geolocator = Nominatim(user_agent="me_explorer")
location = geolocator.geocode(address)
latitude_me = location.latitude
longitude_me = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude_me, longitude_me))
# Out:
# The geograpical coordinate of Toronto are 44.310545, -69.7792759.

# %%
LIMIT = 500 # limit of number of venues returned by Foursquare API



radius = 100000 # define radius

# create URL
url_me = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&sortByPopularity=1&categoryId=4bf58dd8d48988d1e0931735,4bf58dd8d48988d16d941735'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude_me, 
    longitude_me,
    radius,
    LIMIT)
url_me # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=C4MNDL1LR5W55W5YGR2VTH3WFM40JKALTLRJWHAA153YWUFS&client_secret=IMMVE4P4CMKN0PVUHTRX3NGRFMMN1APMJICKBIC0UXCSZDKT&v=20180605&ll=44.310545,-69.7792759&radius=100000&limit=500&sortByPopularity=1&categoryId=4bf58dd8d48988d1e0931735,4bf58dd8d48988d16d941735'

# %%
results_me = requests.get(url_me).json()
results_me
# Out:
# {'meta': {'code': 200, 'requestId': '60e8740619f1ea55ddea6a0b'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Augusta',
#   'headerFullLocation': 'Augusta',
#   'headerLocationGranularity': 'city',
#   'query': 'coffee shop',
#   'totalResults': 165,
#   'suggestedBounds': {'ne': {'lat': 45.210545900000895,
#     'lng': -68.52387419288375},
#    'sw': {'lat': 43.4105440999991, 'lng': -71.03467760711625}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '570ffd5fcd10b0249f84ced8',
#        'name': 'Tim Hortons',
#        'location': {'address': '165 Hinckley Rd,',
#         'lat': 44.640163,
#         'lng': -69.524944,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.640163,
#           'lng': -69.524944}],
#         'distance': 41886,
#         'cc': 'US',
#         'city': 'Clinton',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['165 Hinckley Rd,',
#          'Clinton, ME',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-570ffd5fcd10b0249f84ced8-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b782be9f964a520b3b92ee3',
#        'name': 'The Olde Post Office Cafe',
#        'location': {'address': 'Main Street',
#         'lat': 44.500337852747876,
#         'lng': -69.98805123097219,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.500337852747876,
#           'lng': -69.98805123097219}],
#         'distance': 26870,
#         'postalCode': '04352',
#         'cc': 'US',
#         'city': 'Mount Vernom',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['Main Street',
#          'Mount Vernom, ME 04352',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b782be9f964a520b3b92ee3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c39b16d3849c9288caac1b1',
#        'name': 'The Harbor Cafe',
#        'location': {'address': 'Main St',
#         'lat': 44.15606736028096,
#         'lng': -68.66445493689939,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.15606736028096,
#           'lng': -68.66445493689939}],
#         'distance': 90565,
#         'postalCode': '04627',
#         'cc': 'US',
#         'city': 'Deer Isle',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['Main St',
#          'Deer Isle, ME 04627',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c39b16d3849c9288caac1b1-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5496da7d498e5586ee176c6d',
#        'name': "Aroma Joe's",
#        'location': {'address': '704 Roosevelt Trail',
#         'lat': 43.830421928423334,
#         'lng': -70.43558490481605,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.830421928423334,
#           'lng': -70.43558490481605}],
#         'distance': 74912,
#         'postalCode': '04062',
#         'cc': 'US',
#         'city': 'Town of Windham',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['704 Roosevelt Trail',
#          'Town of Windham, ME 04062',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5496da7d498e5586ee176c6d-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '566c8473498e2a38e9c38a9d',
#        'name': 'Aroma Joes',
#        'location': {'lat': 43.68076902700924,
#         'lng': -70.43878449290828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.68076902700924,
#           'lng': -70.43878449290828}],
#         'distance': 87773,
#         'cc': 'US',
#         'city': 'Gorham',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['Gorham, ME', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-566c8473498e2a38e9c38a9d-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4efb3deb5c5c68fa0ec47b93',
#        'name': '44 North Coffee',
#        'location': {'address': '11 Church St.',
#         'crossStreet': 'Rt. 15',
#         'lat': 44.22368240356445,
#         'lng': -68.67811584472656,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.22368240356445,
#           'lng': -68.67811584472656}],
#         'distance': 88308,
#         'postalCode': '04627',
#         'cc': 'US',
#         'city': 'Deer Isle',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['11 Church St. (Rt. 15)',
#          'Deer Isle, ME 04627',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4efb3deb5c5c68fa0ec47b93-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e1efb7f45dd3be9c478d8c3',
#        'name': 'Bru Thru Coffee Shop',
#        'location': {'address': '180 Gray Rd',
#         'lat': 43.8151667113927,
#         'lng': -70.31401987606431,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.8151667113927,
#           'lng': -70.31401987606431}],
#         'distance': 69789,
#         'postalCode': '04021',
#         'cc': 'US',
#         'city': 'Cumberland Center',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['180 Gray Rd',
#          'Cumberland Center, ME 04021',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e1efb7f45dd3be9c478d8c3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5df1483ff8f55f00088e34c0',
#        'name': "Dunkin'",
#        'location': {'address': '60 Fair St',
#         'lat': 44.2114654,
#         'lng': -70.5298236,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.2114654,
#           'lng': -70.5298236}],
#         'distance': 60843,
#         'postalCode': '04268',
#         'cc': 'US',
#         'city': 'Norway',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['60 Fair St',
#          'Norway, ME 04268',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5df1483ff8f55f00088e34c0-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f903a25e4b08140620bccb9',
#        'name': "Fiona's Catering & Take-Out",
#        'location': {'address': '528 Washington St',
#         'lat': 43.903829,
#         'lng': -69.815884,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.903829,
#           'lng': -69.815884}],
#         'distance': 45369,
#         'postalCode': '04530',
#         'cc': 'US',
#         'city': 'Bath',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['528 Washington St',
#          'Bath, ME 04530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f903a25e4b08140620bccb9-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5df1483fd2bf72000871e8ba',
#        'name': "Dunkin'",
#        'location': {'address': '50 Bay St',
#         'lat': 44.54152809755821,
#         'lng': -69.62639309445996,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.54152809755821,
#           'lng': -69.62639309445996}],
#         'distance': 28440,
#         'postalCode': '04901',
#         'cc': 'US',
#         'city': 'Winslow',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['50 Bay St',
#          'Winslow, ME 04901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2211440',
#         'url': 'https://www.grubhub.com/restaurant/dunkin-50-bay-st-winslow/2211440?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2211440',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5df1483fd2bf72000871e8ba-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba50adef964a520a5d438e3',
#        'name': "Aroma Joe's",
#        'location': {'address': '519 Warren Ave',
#         'lat': 43.686991695170235,
#         'lng': -70.3205186397853,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.686991695170235,
#           'lng': -70.3205186397853}],
#         'distance': 81832,
#         'postalCode': '04103',
#         'cc': 'US',
#         'city': 'Westbrook',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['519 Warren Ave',
#          'Westbrook, ME 04103',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2713595',
#         'url': 'https://www.grubhub.com/restaurant/aroma-joes-519-warren-avenue-portland/2713595?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2713595',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba50adef964a520a5d438e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56512d09498e63f6c4dc9a3e',
#        'name': "Aroma Joe's",
#        'location': {'address': '10 Ossipee Trail W',
#         'lat': 43.73563003540039,
#         'lng': -70.5522232055664,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.73563003540039,
#           'lng': -70.5522232055664}],
#         'distance': 89014,
#         'postalCode': '04084',
#         'cc': 'US',
#         'city': 'Standish',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['10 Ossipee Trail W',
#          'Standish, ME 04084',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '146866464'}},
#       'referralId': 'e-0-56512d09498e63f6c4dc9a3e-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b42124625fb7b002c4b951f',
#        'name': 'Cumberland Food Company',
#        'location': {'lat': 43.796341,
#         'lng': -70.257796,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.796341,
#           'lng': -70.257796}],
#         'distance': 68862,
#         'postalCode': '04021',
#         'cc': 'US',
#         'city': 'Cumberland Center',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['Cumberland Center, ME 04021', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b42124625fb7b002c4b951f-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b705323f964a520c4122de3',
#        'name': 'Bell the Cat, Inc.',
#        'location': {'address': '15 G Starrett Dr',
#         'lat': 44.423404548321635,
#         'lng': -69.02001858148478,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.423404548321635,
#           'lng': -69.02001858148478},
#          {'label': 'entrance', 'lat': 44.422799, 'lng': -69.019797}],
#         'distance': 61713,
#         'postalCode': '04915',
#         'cc': 'US',
#         'city': 'Belfast',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['15 G Starrett Dr',
#          'Belfast, ME 04915',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '1358696361'}},
#       'referralId': 'e-0-4b705323f964a520c4122de3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5617003f498e38d4b7662cc2',
#        'name': 'Starbucks',
#        'location': {'address': '274 Western Ave',
#         'crossStreet': 'at Journal Sq',
#         'lat': 44.31464668,
#         'lng': -69.80438047,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.31464668,
#           'lng': -69.80438047}],
#         'distance': 2051,
#         'postalCode': '04330',
#         'cc': 'US',
#         'city': 'Augusta',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['274 Western Ave (at Journal Sq)',
#          'Augusta, ME 04330',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5617003f498e38d4b7662cc2-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '540065b3498eb6d9e1d19500',
#        'name': 'Tandem Coffee + Bakery',
#        'location': {'address': '742 Congress St',
#         'lat': 43.65313135556721,
#         'lng': -70.27060621434846,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65313135556721,
#           'lng': -70.27060621434846},
#          {'label': 'entrance', 'lat': 43.653171, 'lng': -70.270492}],
#         'distance': 83093,
#         'postalCode': '04102',
#         'cc': 'US',
#         'city': 'Portland',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['742 Congress St',
#          'Portland, ME 04102',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '558784469'}},
#       'referralId': 'e-0-540065b3498eb6d9e1d19500-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0a98847e3fc92874e0f382',
#        'name': 'Trevett Store',
#        'location': {'address': 'W Barters Island Rd',
#         'lat': 43.881388616603815,
#         'lng': -69.67093531076515,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.881388616603815,
#           'lng': -69.67093531076515}],
#         'distance': 48552,
#         'postalCode': '04571',
#         'cc': 'US',
#         'city': 'Boothbay',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['W Barters Island Rd',
#          'Boothbay, ME 04571',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0a98847e3fc92874e0f382-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bcbce7066fc65002c7782f8',
#        'name': 'Aroma Joe’s',
#        'location': {'lat': 43.62116,
#         'lng': -70.304187,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.62116,
#           'lng': -70.304187}],
#         'distance': 87509,
#         'postalCode': '04106',
#         'cc': 'US',
#         'city': 'South Portland',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['South Portland, ME 04106', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2713080',
#         'url': 'https://www.grubhub.com/restaurant/aroma-joes-633-main-street-south-portland/2713080?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2713080',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bcbce7066fc65002c7782f8-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ce1e30a89e490003949760f',
#        'name': 'Starbucks',
#        'location': {'address': '230 Waterman Dr',
#         'lat': 43.63600158691406,
#         'lng': -70.2557601928711,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63600158691406,
#           'lng': -70.2557601928711}],
#         'distance': 84234,
#         'postalCode': '04106',
#         'cc': 'US',
#         'city': 'South Portland',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['230 Waterman Dr',
#          'South Portland, ME 04106',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ce1e30a89e490003949760f-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '575d894b498e140b4b7d77a7',
#        'name': 'St. George River Cafe',
#        'location': {'address': '310 Main St',
#         'crossStreet': 'Four Rod Rd',
#         'lat': 44.12063,
#         'lng': -69.241516,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.12063,
#           'lng': -69.241516}],
#         'distance': 47830,
#         'postalCode': '04864',
#         'cc': 'US',
#         'city': 'Warren',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['310 Main St (Four Rod Rd)',
#          'Warren, ME 04864',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-575d894b498e140b4b7d77a7-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac0dc1ef964a520bf9420e3',
#        'name': 'Bard Coffee',
#        'location': {'address': '185 Middle St',
#         'crossStreet': 'Exchange St.',
#         'lat': 43.65769136469212,
#         'lng': -70.25495382015741,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65769136469212,
#           'lng': -70.25495382015741},
#          {'label': 'entrance', 'lat': 43.657603, 'lng': -70.255226}],
#         'distance': 82056,
#         'postalCode': '04101',
#         'cc': 'US',
#         'city': 'Portland',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['185 Middle St (Exchange St.)',
#          'Portland, ME 04101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac0dc1ef964a520bf9420e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ff002c8b36a69587c6c2ed1',
#        'name': "Dunkin'",
#        'location': {'address': '8 Mile Hill Rd',
#         'lat': 44.637,
#         'lng': -70.0,
#         'labeledLatLngs': [{'label': 'display', 'lat': 44.637, 'lng': -70.0}],
#         'distance': 40348,
#         'postalCode': '04955',
#         'cc': 'US',
#         'city': 'New Sharon',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['8 Mile Hill Rd',
#          'New Sharon, ME 04955',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ff002c8b36a69587c6c2ed1-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58cc3b00ef787f1c206dfb32',
#        'name': 'Coffee ME Up',
#        'location': {'lat': 43.661198837420756,
#         'lng': -70.25628570217334,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.661198837420756,
#           'lng': -70.25628570217334},
#          {'label': 'entrance', 'lat': 43.661128, 'lng': -70.2564}],
#         'distance': 81759,
#         'postalCode': '04101',
#         'cc': 'US',
#         'city': 'Portland',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['Portland, ME 04101', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1324276',
#         'url': 'https://www.grubhub.com/restaurant/coffee-me-up-221-cumberland-avenue-portland/1324276?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1324276',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58cc3b00ef787f1c206dfb32-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf8033db182c9b686a3765a',
#        'name': 'Village Tie Up',
#        'location': {'address': '29 Main St.',
#         'crossStreet': 'harrison heights rd.',
#         'lat': 44.1109655938464,
#         'lng': -70.68140711391435,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.1109655938464,
#           'lng': -70.68140711391435}],
#         'distance': 75332,
#         'postalCode': '04040',
#         'cc': 'US',
#         'city': 'Harrison',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['29 Main St. (harrison heights rd.)',
#          'Harrison, ME 04040',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf8033db182c9b686a3765a-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae836fff964a52039ae21e3',
#        'name': 'Stones Café & Bakery',
#        'location': {'address': '424 Walnut Hill Rd',
#         'lat': 43.82666599011166,
#         'lng': -70.24762689106959,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.82666599011166,
#           'lng': -70.24762689106959}],
#         'distance': 65609,
#         'postalCode': '04097',
#         'cc': 'US',
#         'city': 'Town of North Yarmouth',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['424 Walnut Hill Rd',
#          'Town of North Yarmouth, ME 04097',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae836fff964a52039ae21e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55562a67498e752c8df365ee',
#        'name': 'Bomb Diggity Bakery & Cafe',
#        'location': {'address': '781 Roosevelt Trl',
#         'lat': 43.83767246921348,
#         'lng': -70.44102494190223,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.83767246921348,
#           'lng': -70.44102494190223}],
#         'distance': 74644,
#         'postalCode': '04062',
#         'cc': 'US',
#         'city': 'Town of Windham',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['781 Roosevelt Trl',
#          'Town of Windham, ME 04062',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55562a67498e752c8df365ee-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5f5bd2cbaf65ef27d8b3a45d',
#        'name': 'Speckled Ax',
#        'location': {'address': '18 Thames St',
#         'lat': 43.659806,
#         'lng': -70.247805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.659806,
#           'lng': -70.247805}],
#         'distance': 81582,
#         'postalCode': '04101',
#         'cc': 'US',
#         'city': 'Portland',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['18 Thames St',
#          'Portland, ME 04101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2701473',
#         'url': 'https://www.grubhub.com/restaurant/speckled-ax-18-thames-street-portland/2701473?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2701473',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5f5bd2cbaf65ef27d8b3a45d-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb68bb6941ad13a99a01fe3',
#        'name': "Gloria Jean's Coffees",
#        'location': {'address': '225 Maine Mall Rd. Space # W-123',
#         'lat': 43.63413677237489,
#         'lng': -70.33648639528283,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63413677237489,
#           'lng': -70.33648639528283}],
#         'distance': 87534,
#         'postalCode': '04106',
#         'cc': 'US',
#         'city': 'South Portland',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['225 Maine Mall Rd. Space # W-123',
#          'South Portland, ME 04106',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1474115',
#         'url': 'https://www.grubhub.com/restaurant/gloria-jeans-coffees-364-maine-mall-road-south-portland/1474115?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1474115',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb68bb6941ad13a99a01fe3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '592c0d1cca18ea4708e6d6ee',
#        'name': 'Wicked Brew',
#        'location': {'address': 'Park Street',
#         'lat': 44.80529903726811,
#         'lng': -68.77065812684748,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.80529903726811,
#           'lng': -68.77065812684748}],
#         'distance': 97126,
#         'postalCode': '04401',
#         'cc': 'US',
#         'city': 'Bangor',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['Park Street',
#          'Bangor, ME 04401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1641705',
#         'url': 'https://www.grubhub.com/restaurant/wicked-brew-coffee-bar-173-park-street-bangor/1641705?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1641705',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-592c0d1cca18ea4708e6d6ee-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be17d2b8e2962b5a2579b0a',
#        'name': 'Starbucks',
#        'location': {'address': '2 Waterville Commons Dr',
#         'crossStreet': 'at The Small Shops at Waterville Commons',
#         'lat': 44.57065766,
#         'lng': -69.64231074,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.57065766,
#           'lng': -69.64231074},
#          {'label': 'entrance', 'lat': 44.570587, 'lng': -69.642345}],
#         'distance': 30934,
#         'postalCode': '04901',
#         'cc': 'US',
#         'city': 'Waterville',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['2 Waterville Commons Dr (at The Small Shops at Waterville Commons)',
#          'Waterville, ME 04901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be17d2b8e2962b5a2579b0a-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e9c68949a52edbd6618dec8',
#        'name': 'B.I.G.S. Bailey Island General Store',
#        'location': {'lat': 43.735784064815185,
#         'lng': -69.99558554689405,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.735784064815185,
#           'lng': -69.99558554689405}],
#         'distance': 66283,
#         'postalCode': '04003',
#         'cc': 'US',
#         'city': 'Harpswell',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['Harpswell, ME 04003', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e9c68949a52edbd6618dec8-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c4c80a59c8d2d7fb4bd846c',
#        'name': 'Belfast Co-op',
#        'location': {'address': '123 High St',
#         'crossStreet': 'High & Pendleton',
#         'lat': 44.42617974925733,
#         'lng': -69.00558850656888,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.42617974925733,
#           'lng': -69.00558850656888},
#          {'label': 'entrance', 'lat': 44.426308, 'lng': -69.005349}],
#         'distance': 62898,
#         'postalCode': '04915',
#         'cc': 'US',
#         'city': 'Belfast',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['123 High St (High & Pendleton)',
#          'Belfast, ME 04915',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '59584702'}},
#       'referralId': 'e-0-4c4c80a59c8d2d7fb4bd846c-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e04cdd7b61c6b32fb080aa5',
#        'name': 'Airport Coffee Shop',
#        'location': {'address': '287 Godfrey Blvd',
#         'crossStreet': 'Maine Avenue',
#         'lat': 44.80814468835093,
#         'lng': -68.8166431216446,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.80814468835093,
#           'lng': -68.8166431216446}],
#         'distance': 94328,
#         'postalCode': '04401',
#         'cc': 'US',
#         'city': 'Bangor',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['287 Godfrey Blvd (Maine Avenue)',
#          'Bangor, ME 04401',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e04cdd7b61c6b32fb080aa5-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b45dd0cf964a520551126e3',
#        'name': 'Coffee By Design',
#        'location': {'address': '67 India St',
#         'crossStreet': 'at Newbury St',
#         'lat': 43.66087188616507,
#         'lng': -70.25057397557813,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66087188616507,
#           'lng': -70.25057397557813},
#          {'label': 'entrance', 'lat': 43.660781, 'lng': -70.250386}],
#         'distance': 81579,
#         'postalCode': '04101',
#         'cc': 'US',
#         'city': 'Portland',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['67 India St (at Newbury St)',
#          'Portland, ME 04101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1787301',
#         'url': 'https://www.grubhub.com/restaurant/coffee-by-design-67-india-st-portland/1787301?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1787301',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b45dd0cf964a520551126e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52a5038811d2da854051d9bf',
#        'name': 'Coffee By Design',
#        'location': {'address': '1 Diamond St',
#         'lat': 43.6660830980612,
#         'lng': -70.25674100814265,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6660830980612,
#           'lng': -70.25674100814265},
#          {'label': 'entrance', 'lat': 43.665968, 'lng': -70.256629}],
#         'distance': 81296,
#         'postalCode': '04101',
#         'cc': 'US',
#         'city': 'Portland',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['1 Diamond St',
#          'Portland, ME 04101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1474131',
#         'url': 'https://www.grubhub.com/restaurant/coffee-by-design-1-diamond-street-portland/1474131?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1474131',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52a5038811d2da854051d9bf-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fad64e9e4b06d18cc5ab9f7',
#        'name': 'Speckled Ax',
#        'location': {'address': '567 Congress St',
#         'crossStreet': 'Oak St',
#         'lat': 43.65496003631834,
#         'lng': -70.26221853177948,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65496003631834,
#           'lng': -70.26221853177948},
#          {'label': 'entrance', 'lat': 43.654983, 'lng': -70.262302}],
#         'distance': 82597,
#         'postalCode': '04101',
#         'cc': 'US',
#         'city': 'Portland',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['567 Congress St (Oak St)',
#          'Portland, ME 04101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fad64e9e4b06d18cc5ab9f7-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58ceae98110d037d32e0fe10',
#        'name': "Aroma Joe's",
#        'location': {'lat': 44.108279,
#         'lng': -70.226195,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.108279,
#           'lng': -70.226195}],
#         'distance': 42174,
#         'postalCode': '04210',
#         'cc': 'US',
#         'city': 'Auburn',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['Auburn, ME 04210', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
# ...
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1474826',
#         'url': 'https://www.grubhub.com/restaurant/rwanda-bean-coffee-463-stevens-avenue-portland/1474826?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1474826',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b719f1c037be1002c198729-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4df9193b45dd816eb5a913db',
#        'name': 'Salt Cod Cafe',
#        'location': {'lat': 43.75088325429706,
#         'lng': -69.98698573863341,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75088325429706,
#           'lng': -69.98698573863341}],
#         'distance': 64480,
#         'cc': 'US',
#         'state': 'Maine',
#         'country': 'United States',
#         'formattedAddress': ['Maine', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4df9193b45dd816eb5a913db-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1c22dab4e62d7fd6a4da93',
#        'name': 'Black Bear Cafe',
#        'location': {'address': '215 Roosevelt Trl',
#         'lat': 43.96351127099047,
#         'lng': -70.5735612775761,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.96351127099047,
#           'lng': -70.5735612775761}],
#         'distance': 74289,
#         'postalCode': '04055',
#         'cc': 'US',
#         'city': 'Naples',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['215 Roosevelt Trl',
#          'Naples, ME 04055',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1c22dab4e62d7fd6a4da93-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b66d326f964a5204d2c2be3',
#        'name': 'Scarborough Grounds',
#        'location': {'address': 'W City Ave.',
#         'crossStreet': 'Ward St.',
#         'lat': 43.58909918108991,
#         'lng': -70.33970118351371,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.58909918108991,
#           'lng': -70.33970118351371}],
#         'distance': 92016,
#         'postalCode': '04074',
#         'cc': 'US',
#         'city': 'Scarborough',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['W City Ave. (Ward St.)',
#          'Scarborough, ME 04074',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1474611',
#         'url': 'https://www.grubhub.com/restaurant/scarborough-grounds-264-us-1-scarborough/1474611?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1474611',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b66d326f964a5204d2c2be3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54f7551c498e22410fd84ed1',
#        'name': 'Shipwreck Coffee Company',
#        'location': {'address': '591 Maine Ave',
#         'lat': 44.260059000000005,
#         'lng': -69.77773499999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.260059000000005,
#           'lng': -69.77773499999999},
#          {'label': 'entrance', 'lat': 44.260031, 'lng': -69.777776}],
#         'distance': 5621,
#         'postalCode': '04344',
#         'cc': 'US',
#         'city': 'Farmingdale',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['591 Maine Ave',
#          'Farmingdale, ME 04344',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1270526',
#         'url': 'https://www.grubhub.com/restaurant/shipwreck-coffee-company-591-maine-ave-farmingdale/1270526?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1270526',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54f7551c498e22410fd84ed1-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bfc0658aedcef3b17315a5f',
#        'name': 'Verbena',
#        'location': {'address': '103 Ocean St',
#         'lat': 43.63873075792448,
#         'lng': -70.25324387656659,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63873075792448,
#           'lng': -70.25324387656659}],
#         'distance': 83872,
#         'postalCode': '04106',
#         'cc': 'US',
#         'city': 'South Portland',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['103 Ocean St',
#          'South Portland, ME 04106',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bfc0658aedcef3b17315a5f-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc7109892b376b0c6f74e3a',
#        'name': "Isabella's Cafe & Bakery",
#        'location': {'address': '2 School St',
#         'lat': 43.85845727815326,
#         'lng': -70.10201055981574,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.85845727815326,
#           'lng': -70.10201055981574},
#          {'label': 'entrance', 'lat': 43.858422, 'lng': -70.101936}],
#         'distance': 56556,
#         'postalCode': '04032',
#         'cc': 'US',
#         'city': 'Freeport',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['2 School St',
#          'Freeport, ME 04032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc7109892b376b0c6f74e3a-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b22a47873fe25002c9b38b5',
#        'name': 'Dog Bar Jim',
#        'location': {'address': 'Union Street',
#         'lat': 43.910362,
#         'lng': -69.967125,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.910362,
#           'lng': -69.967125}],
#         'distance': 47009,
#         'postalCode': '04011',
#         'cc': 'US',
#         'city': 'Brunswick',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['Union Street',
#          'Brunswick, ME 04011',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b22a47873fe25002c9b38b5-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '540b203a498e234757b5ce8c',
#        'name': 'Aroma Joes',
#        'location': {'lat': 44.19380099915643,
#         'lng': -70.52531284348976,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.19380099915643,
#           'lng': -70.52531284348976}],
#         'distance': 60888,
#         'cc': 'US',
#         'city': 'Oxford',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['Oxford, ME', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-540b203a498e234757b5ce8c-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8c4efcf964a520ccc932e3',
#        'name': 'Little Dog Coffee Shop',
#        'location': {'address': '87 Maine St',
#         'crossStreet': 'at Bank St.',
#         'lat': 43.916533674073044,
#         'lng': -69.96574367578647,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.916533674073044,
#           'lng': -69.96574367578647}],
#         'distance': 46323,
#         'postalCode': '04011',
#         'cc': 'US',
#         'city': 'Brunswick',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['87 Maine St (at Bank St.)',
#          'Brunswick, ME 04011',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8c4efcf964a520ccc932e3-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc0db92b492d13aef06a560',
#        'name': "Jorgensen's Cafe",
#        'location': {'address': '103 Main St',
#         'lat': 44.550213269850104,
#         'lng': -69.63018941800075,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 44.550213269850104,
#           'lng': -69.63018941800075},
#          {'label': 'entrance', 'lat': 44.550333, 'lng': -69.630087}],
#         'distance': 29193,
#         'postalCode': '04901',
#         'cc': 'US',
#         'city': 'Waterville',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['103 Main St',
#          'Waterville, ME 04901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc0db92b492d13aef06a560-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f448fce19836ed00194e55e',
#        'name': 'Middle Street Cafe',
#        'location': {'address': '100 Middle St',
#         'lat': 43.658693,
#         'lng': -70.25173,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.658693,
#           'lng': -70.25173},
#          {'label': 'entrance', 'lat': 43.658868, 'lng': -70.252113}],
#         'distance': 81837,
#         'postalCode': '04101',
#         'cc': 'US',
#         'city': 'Portland',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['100 Middle St',
#          'Portland, ME 04101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1787265',
#         'url': 'https://www.grubhub.com/restaurant/middle-street-cafe-100-middle-street-portland/1787265?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1787265',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f448fce19836ed00194e55e-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59e230c56661165eb5114e81',
#        'name': 'Higher Grounds',
#        'location': {'address': '45 Wharf St',
#         'lat': 43.6557577,
#         'lng': -70.2544478,
#         'labeledLatLngs': [{'label': 'entrance',
#           'lat': 43.655761,
#           'lng': -70.254638},
#          {'label': 'display', 'lat': 43.6557577, 'lng': -70.2544478}],
#         'distance': 82228,
#         'postalCode': '04101',
#         'cc': 'US',
#         'city': 'Portland',
#         'state': 'ME',
#         'country': 'United States',
#         'formattedAddress': ['45 Wharf St',
#          'Portland, ME 04101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59e230c56661165eb5114e81-99'}]}]}}

# %%
venues_me = results_me['response']['groups'][0]['items']
    
nearby_venues_me = json_normalize(venues_me) # flatten JSON
# Out:
# <ipython-input-33-d176502235e9>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues_me = json_normalize(venues_me) # flatten JSON

# %%
# filter columns
filtered_columns_me = ['venue.name', 'venue.categories', 'venue.location.city', 'venue.location.state', 'venue.location.lat', 'venue.location.lng']
nearby_venues_me =nearby_venues_me.loc[:, filtered_columns_me]

# filter the category for each row
nearby_venues_me['venue.categories'] = nearby_venues_me.apply(get_category_type, axis=1)

# clean columns
nearby_venues_me.columns = [col.split(".")[-1] for col in nearby_venues_me.columns]

nearby_venues_me.head()
# Out:
#                         name   categories             city state        lat  \
# 0                Tim Hortons  Coffee Shop          Clinton    ME  44.640163
# 1  The Olde Post Office Cafe         Café     Mount Vernom    ME  44.500338
# 2            The Harbor Cafe         Café        Deer Isle    ME  44.156067
# 3                Aroma Joe's  Coffee Shop  Town of Windham    ME  43.830422
# 4                 Aroma Joes  Coffee Shop           Gorham    ME  43.680769
#
#          lng
# 0 -69.524944
# 1 -69.988051
# 2 -68.664455
# 3 -70.435585
# 4 -70.438784
